# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential, Model
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, GlobalMaxPooling2D
from sklearn.utils import shuffle
from tensorflow.keras import utils
from tensorflow import concat
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
# Out:
# 2023-10-11 08:53:40.124124: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-11 08:53:40.182097: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-11 08:53:41.145962: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
with h5py.File('Galaxy10_DECals.h5', 'r') as F:
    images = np.array(F['images'])#这一步是读取图片
    labels = np.array(F['ans'])#这一步是读取图片的标签
    
images = images.astype(np.float32)#这一步是将图片转为float32类型   

labels = utils.to_categorical(labels, 10)#这一步是使用one-hot编码，一个10个类
labels = labels.astype(np.float32)#这一步是图片将图片的标签转为float32类型

# %%
(images, labels) = shuffle(images, labels)#这一步是打乱图片和其标签的排列顺序

# %%
#classes是类对应的英文名字，是否正确对应未检查。
classes = ['Disturbed Galaxies','Merging Galaxies','Round Smooth Galaxies','In-between Round Smooth Galaxies','Cigar Shaped Smooth Galaxies','Barred Spiral Galaxies','Unbarred Tight Spiral Galaxies','Unbarred Loose Spiral Galaxies','Edge-on Galaxies without Bulge','Edge-on Galaxies with Bulge']
class_labels = {classes:i for classes, i in enumerate(classes)}#生成类别名字到标号的对应关系，是否正确对应未检查。
print(class_labels)
# Out:
# {0: 'Disturbed Galaxies', 1: 'Merging Galaxies', 2: 'Round Smooth Galaxies', 3: 'In-between Round Smooth Galaxies', 4: 'Cigar Shaped Smooth Galaxies', 5: 'Barred Spiral Galaxies', 6: 'Unbarred Tight Spiral Galaxies', 7: 'Unbarred Loose Spiral Galaxies', 8: 'Edge-on Galaxies without Bulge', 9: 'Edge-on Galaxies with Bulge'}

# %%
#显示图片及其类别
plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[i]/255.)
    plt.xlabel(class_labels[int(np.argwhere(labels[i]==1))])
plt.show()

# %%
#SeNet的特征
class SeBlock(Model):
    def __init__(self, planes):
        super(SeBlock, self).__init__()
        self.se = Sequential()
        self.se.add(GlobalAveragePooling2D(keepdims=True))
        self.se.add(Conv2D(planes,kernel_size=(1,1),strides=(1, 1),padding='same'))
        self.se.add(Activation('gelu'))
        self.se.add(Conv2D(planes,kernel_size=(1,1),strides=(1, 1),padding='same'))
        self.se.add(Activation('sigmoid'))
    def call(self, inputs):
        out = self.se(inputs)
        return out

# %%
#ResNet的特征
class BasicBlock(Model):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.basic = Sequential()
        self.basic.add(Conv2D(planes,kernel_size=(3,3),strides=(stride, stride),padding='same')) 
        self.basic.add(BatchNormalization())
        self.basic.add(Activation('gelu'))
        self.basic.add(Conv2D(planes,kernel_size=(3,3),strides=(1, 1),padding='same'))
        self.basic.add(BatchNormalization())
        self.se1 = SeBlock(planes=planes)
        self.shortcut = Sequential()
        if in_planes!=planes or stride!=1:
            self.shortcut.add(Conv2D(planes,kernel_size=(1,1),strides=(stride, stride),padding='same'))
            self.shortcut.add(BatchNormalization())
        self.a2 = Activation('gelu')
    def call(self, inputs):
        out = self.basic(inputs)
        w = self.se1(out)
        out = out * w
        residual=self.shortcut(inputs)
        out = self.a2(residual+out)
        return out

# %%
#DlaNet的特征
class Root(Model):
    def __init__(self, planes, kernel_size=1):
        super(Root, self).__init__()
        self.basic = Sequential()
        self.basic.add(Conv2D(planes,kernel_size=(kernel_size,kernel_size),strides=(1, 1),padding='same'))
        self.basic.add(BatchNormalization())
        self.basic.add(Activation('gelu'))
    def call(self, inputs):
        out = concat(inputs, axis=-1)
        out = self.basic(out)
        return out

# %%
#DlaNet的特征
class Tree(Model):
    def __init__(self, in_planes, planes, level=1, stride=1):
        super(Tree, self).__init__()
        self.level = level
        if level == 1:
            self.root = Root(planes)
            self.left_node = BasicBlock(in_planes, planes, stride=stride)
            self.right_node = BasicBlock(planes, planes, stride=1)
        else:
            self.root = Root(planes)
            self.subtrees={}
            for i in reversed(range(1, level)):
                if i==level-1:
                    subtree = Tree(in_planes, planes, level=i, stride=stride)
                else:
                    subtree = Tree(planes, planes, level=i, stride=stride)
                self.subtrees[f'level_{i}'] = subtree
            self.prev_root = BasicBlock(in_planes, planes, stride=stride)
            self.left_node = BasicBlock(planes, planes, stride=1)
            self.right_node = BasicBlock(planes, planes, stride=1)
    def call(self, inputs):
        out = inputs
        outs = [self.prev_root(out)] if self.level > 1 else []
        for i in reversed(range(1, self.level)):
            level_i = self.subtrees[f'level_{i}']
            out = level_i(out)
            outs.append(out)
        out = self.left_node(out)
        outs.append(out)
        out = self.right_node(out)
        outs.append(out)
        out = self.root(outs)
        return out

# %%
#该模型没有同池化操作下采样，处理SeNet生成权值w部分，使用激活函数包括sigmoid，tanh，gelu
class CNN_net(Model):
    def __init__(self, model):
        super(CNN_net, self).__init__()
        self.stem = Sequential()
        self.stem.add(Conv2D(16,kernel_size=(5,5),strides=(1, 1),padding='same'))#256
        self.stem.add(BatchNormalization())
        self.stem.add(Activation('gelu'))
        self.stem.add(Conv2D(32,kernel_size=(3,3),strides=(1, 1),padding='same'))#256
        self.stem.add(BatchNormalization())
        self.stem.add(Activation('gelu'))
        self.stem.add(Conv2D(32,kernel_size=(3,3),strides=(2, 2),padding='same'))#128
        self.stem.add(BatchNormalization())
        self.stem.add(Activation('gelu'))
        
        self.blocks = Sequential()
        self.blocks.add(Tree(32,  64, level=2, stride=1))##128
        self.blocks.add(Tree(64,  128, level=2, stride=2))#64
        self.blocks.add(Tree(128,  256, level=2, stride=2))#32
        self.blocks.add(Tree(256,  512, level=2, stride=2))#16
        self.blocks.add(Tree(512,  1024, level=2, stride=2))#8
        self.blocks.add(Tree(1024,  2048, level=2, stride=2))#4
        self.blocks.add(Conv2D(2048,kernel_size=(4,4),strides=(1, 1),padding='valid'))#1
        self.blocks.add(BatchNormalization())
        self.blocks.add(Activation('gelu'))
        
        self.fullconnected = Sequential()
        self.fullconnected.add(Flatten())
        self.fullconnected.add(Dense(1024, activation='linear'))
        self.fullconnected.add(BatchNormalization())
        self.fullconnected.add(Activation('tanh'))
        self.fullconnected.add(Dense(1024, activation='linear'))
        self.fullconnected.add(BatchNormalization())
        self.fullconnected.add(Activation('tanh'))
        self.fullconnected.add(Dense(1024, activation='linear'))
        self.fullconnected.add(BatchNormalization())
        self.fullconnected.add(Activation('tanh'))
        
        self.out = Sequential()
        if model=='regression':
            self.out.add(Dense(1, activation='linear'))
        if model=='classification':
            self.out.add(Dense(10, activation='softmax'))
        
    def call(self, inputs):
        out = self.stem(inputs)
        out = self.blocks(out)
        out = self.fullconnected(out)
        out = self.out(out)
        return out

# %%
model_classification = CNN_net(model='classification')#生成用于classification的模型
# Out:
# 2023-10-11 08:55:06.130050: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-11 08:55:06.172137: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-11 08:55:06.172652: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-11 08:55:06.175136: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-11 08:55:06.175616: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-11 08:55:06.176002: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-11 08:55:07.050998: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-11 08:55:07.051446: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-11 08:55:07.051757: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-11 08:55:07.052059: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22291 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0b:00.0, compute capability: 8.6

# %%
model_classification.build(input_shape=(None, 256, 256, 3))#定义模型的input_shape
model_classification.summary()#生成模型的总结
# Out:
# Model: "cnn_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 128, 128, 32)      15424
#
#  sequential_1 (Sequential)   (None, 1, 1, 2048)        615363584
#
#  sequential_104 (Sequential  (None, 1024)              4209664
#  )
#
#  sequential_105 (Sequential  (None, 10)                10250
#  )
#
# =================================================================
# Total params: 619598922 (2.31 GB)
# Trainable params: 619475626 (2.31 GB)
# Non-trainable params: 123296 (481.62 KB)
# _________________________________________________________________

# %%
#这里是使用SGDR的参数
#initial_learning_rate = 0.1
#first_decay_steps = 1000
#t_mul = 2.0
#m_mul = 1.0
#alpha = 0.0

# %%
#这里是使用SGDR编译模型
#checkpoint_save_path = r'saved_modle_classification'
#lr_reducer = tf.keras.optimizers.schedules.CosineDecayRestarts(initial_learning_rate, first_decay_steps, t_mul=2.0, m_mul=1.0, alpha=0.0)
#model_classification.compile(optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=lr_reducer,momentum=0.9,nesterov=True,weight_decay=5e-4),loss=tf.keras.losses.CategoricalCrossentropy(),metrics=tf.keras.metrics.CategoricalAccuracy())

# %%
#这里是使用AdamW编译模型，并用ReduceLROnPlateau调整训练中的学习率
model_classification.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=0.01),loss=tf.keras.losses.CategoricalCrossentropy(),metrics=tf.keras.metrics.CategoricalAccuracy())
lr_reducer = ReduceLROnPlateau(monitor='val_loss',factor=0.2,patience=10,mode='min',min_lr=1e-20)

# %%
checkpoint_save_path = 'modelsave.h5'#这里是模型的路径
model_classification.load_weights(filepath=checkpoint_save_path)#这里是加载模型

# %%
train_datagen = ImageDataGenerator(
    featurewise_center=True,#将输入数据的每个样本减去整个数据集的均值，使得数据的均值为0。这有助于使数据集的均值接近于零。
    featurewise_std_normalization=True,#将输入数据的每个样本除以整个数据集的标准差，以使数据的标准差为1。这有助于使数据的标准差接近于1。
    rotation_range=180,#在范围内随机旋转图像，以增加数据的多样性。此参数指定旋转范围为±180度，即任意角度的旋转。
    width_shift_range=0.2,#在水平方向随机平移图像。此参数指定允许图像水平平移的范围为图像宽度的20%。
    height_shift_range=0.2,#在垂直方向随机平移图像。此参数指定允许图像垂直平移的范围为图像高度的20%。
    horizontal_flip=True,#随机水平翻转图像。这可以增加数据的多样性和泛化能力。
    rescale=1/255.,#对输入图像进行缩放，将像素值从0-255缩放到0-1范围之间。这通常是在训练之前对图像进行预处理的常见步骤。
    validation_split=0.2,#指定验证集的比例。在此情况下，20% 的数据将用作验证集，而剩余的 80% 将用于训练。
)

train_datagen.fit(images)#调用 fit 方法来计算输入图像数据的统计信息，包括均值和标准差。这将使用整个数据集来计算这些统计信息，并将它们应用于后续的数据增强和预处理过程中。

# %%
def mixup(batch_x, batch_y, alpha):
    batch_size = len(batch_x)
    lam = np.random.beta(alpha, alpha, size=batch_size)

    index = np.random.permutation(batch_size)
    mixed_x = lam.reshape(batch_size, 1, 1, 1) * batch_x + (1 - lam.reshape(batch_size, 1, 1, 1)) * batch_x[index]
    mixed_y = lam.reshape(batch_size, 1) * batch_y + (1 - lam.reshape(batch_size, 1)) * batch_y[index]

    return mixed_x, mixed_y

# %%
def datagen_generator(images, labels, batch_size, alpha):
    generator = train_datagen.flow(images, labels, batch_size=batch_size,subset='training')
    while True:
        batch_x, batch_y = next(generator)#next(generator) 返回的是使用 train_datagen.flow 生成器生成的下一个批次的图像数据和对应的标签。
        mixed_x, mixed_y = mixup(batch_x, batch_y, alpha)#调用mixup方法生成训练数据与标签
        yield mixed_x, mixed_y#通过使用 yield 语句返回混合后的图像数据和标签，即 yield mixed_x, mixed_y。这样，datagen_generator 函数就变成了一个生成器函数，每次调用它时，都会生成一个新的批次的混合数据。

# %%
batch_size = 16#batch_size大小为16
alpha = 1#alpha为1，代表着beta分布中各个概率出现的可能性相同

# %%
#checkpointer的作用是在训练中保存模型
checkpointer = ModelCheckpoint(filepath=checkpoint_save_path,monitor='val_loss',verbose=1,save_best_only=True,save_weights_only=True)
history_classification = model_classification.fit(#datagen_generator(images, labels, batch_size, alpha),
                                                    train_datagen.flow(images, labels, batch_size=batch_size,subset='training'),
                                                    validation_data=train_datagen.flow(images, labels,batch_size=batch_size, subset='validation'),
                                                    steps_per_epoch=880,
                                                    epochs=200,
                                                    callbacks=[lr_reducer, checkpointer]#调整学习率和保存模型
                                                 )
# Out:
# Epoch 1/200
# 2023-10-11 08:58:08.137073: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8900
# 2023-10-11 08:58:10.657701: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-10-11 08:58:10.663174: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f72b9f5cf60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-11 08:58:10.663318: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-10-11 08:58:10.670173: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-11 08:58:10.845371: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-10-11 08:58:25.890335: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.63GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-11 08:58:34.733580: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.37GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-11 08:58:43.519920: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-11 08:58:52.395408: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.43GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 513/880 [================>.............] - ETA: 3:00 - loss: 0.8148 - categorical_accuracy: 0.7412
# 2023-10-11 09:03:23.479488: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.62GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-11 09:03:24.236576: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.29GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-11 09:03:24.762965: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.36GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 880/880 [==============================] - ETA: 0s - loss: 0.8192 - categorical_accuracy: 0.7382
# Epoch 1: val_loss improved from inf to 1.23407, saving model to modelsave.h5
# 880/880 [==============================] - 617s 582ms/step - loss: 0.8192 - categorical_accuracy: 0.7382 - val_loss: 1.2341 - val_categorical_accuracy: 0.6194 - lr: 0.0100
# Epoch 2/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7931 - categorical_accuracy: 0.7450
# Epoch 2: val_loss improved from 1.23407 to 0.94553, saving model to modelsave.h5
# 880/880 [==============================] - 513s 583ms/step - loss: 0.7931 - categorical_accuracy: 0.7450 - val_loss: 0.9455 - val_categorical_accuracy: 0.6919 - lr: 0.0100
# Epoch 3/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7798 - categorical_accuracy: 0.7498
# Epoch 3: val_loss did not improve from 0.94553
# 880/880 [==============================] - 516s 586ms/step - loss: 0.7798 - categorical_accuracy: 0.7498 - val_loss: 1.4527 - val_categorical_accuracy: 0.5326 - lr: 0.0100
# Epoch 4/200
# 314/880 [=========>....................] - ETA: 4:38 - loss: 0.7741 - categorical_accuracy: 0.7492
# 2023-10-11 09:28:59.579433: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 258.12MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 880/880 [==============================] - ETA: 0s - loss: 0.7923 - categorical_accuracy: 0.7459
# Epoch 4: val_loss did not improve from 0.94553
# 880/880 [==============================] - 475s 540ms/step - loss: 0.7923 - categorical_accuracy: 0.7459 - val_loss: 0.9891 - val_categorical_accuracy: 0.7031 - lr: 0.0100
# Epoch 5/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7891 - categorical_accuracy: 0.7492
# Epoch 5: val_loss did not improve from 0.94553
# 880/880 [==============================] - 475s 540ms/step - loss: 0.7891 - categorical_accuracy: 0.7492 - val_loss: 1.2449 - val_categorical_accuracy: 0.6059 - lr: 0.0100
# Epoch 6/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7836 - categorical_accuracy: 0.7525
# Epoch 6: val_loss did not improve from 0.94553
# 880/880 [==============================] - 474s 539ms/step - loss: 0.7836 - categorical_accuracy: 0.7525 - val_loss: 1.8604 - val_categorical_accuracy: 0.3059 - lr: 0.0100
# Epoch 7/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7758 - categorical_accuracy: 0.7516
# Epoch 7: val_loss did not improve from 0.94553
# 880/880 [==============================] - 477s 541ms/step - loss: 0.7758 - categorical_accuracy: 0.7516 - val_loss: 1.0833 - val_categorical_accuracy: 0.6572 - lr: 0.0100
# Epoch 8/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7830 - categorical_accuracy: 0.7527
# Epoch 8: val_loss did not improve from 0.94553
# 880/880 [==============================] - 476s 540ms/step - loss: 0.7830 - categorical_accuracy: 0.7527 - val_loss: 1.6270 - val_categorical_accuracy: 0.4894 - lr: 0.0100
# Epoch 9/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7684 - categorical_accuracy: 0.7544
# Epoch 9: val_loss did not improve from 0.94553
# 880/880 [==============================] - 477s 541ms/step - loss: 0.7684 - categorical_accuracy: 0.7544 - val_loss: 1.3170 - val_categorical_accuracy: 0.5994 - lr: 0.0100
# Epoch 10/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7595 - categorical_accuracy: 0.7575
# Epoch 10: val_loss did not improve from 0.94553
# 880/880 [==============================] - 481s 546ms/step - loss: 0.7595 - categorical_accuracy: 0.7575 - val_loss: 1.5513 - val_categorical_accuracy: 0.5605 - lr: 0.0100
# Epoch 11/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7710 - categorical_accuracy: 0.7521
# Epoch 11: val_loss did not improve from 0.94553
# 880/880 [==============================] - 475s 539ms/step - loss: 0.7710 - categorical_accuracy: 0.7521 - val_loss: 0.9711 - val_categorical_accuracy: 0.6828 - lr: 0.0100
# Epoch 12/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7736 - categorical_accuracy: 0.7531
# Epoch 12: val_loss improved from 0.94553 to 0.71336, saving model to modelsave.h5
# 880/880 [==============================] - 507s 576ms/step - loss: 0.7736 - categorical_accuracy: 0.7531 - val_loss: 0.7134 - val_categorical_accuracy: 0.7637 - lr: 0.0100
# Epoch 13/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7427 - categorical_accuracy: 0.7584
# Epoch 13: val_loss did not improve from 0.71336
# 880/880 [==============================] - 517s 587ms/step - loss: 0.7427 - categorical_accuracy: 0.7584 - val_loss: 1.5943 - val_categorical_accuracy: 0.4796 - lr: 0.0100
# Epoch 14/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7635 - categorical_accuracy: 0.7584
# Epoch 14: val_loss did not improve from 0.71336
# 880/880 [==============================] - 516s 586ms/step - loss: 0.7635 - categorical_accuracy: 0.7584 - val_loss: 0.8743 - val_categorical_accuracy: 0.7226 - lr: 0.0100
# Epoch 15/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7518 - categorical_accuracy: 0.7588
# Epoch 15: val_loss did not improve from 0.71336
# 880/880 [==============================] - 474s 539ms/step - loss: 0.7518 - categorical_accuracy: 0.7588 - val_loss: 1.2677 - val_categorical_accuracy: 0.6107 - lr: 0.0100
# Epoch 16/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7404 - categorical_accuracy: 0.7617
# Epoch 16: val_loss did not improve from 0.71336
# 880/880 [==============================] - 472s 536ms/step - loss: 0.7404 - categorical_accuracy: 0.7617 - val_loss: 1.0928 - val_categorical_accuracy: 0.5853 - lr: 0.0100
# Epoch 17/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7523 - categorical_accuracy: 0.7626
# Epoch 17: val_loss did not improve from 0.71336
# 880/880 [==============================] - 513s 583ms/step - loss: 0.7523 - categorical_accuracy: 0.7626 - val_loss: 1.3339 - val_categorical_accuracy: 0.5475 - lr: 0.0100
# Epoch 18/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7507 - categorical_accuracy: 0.7620
# Epoch 18: val_loss did not improve from 0.71336
# 880/880 [==============================] - 472s 537ms/step - loss: 0.7507 - categorical_accuracy: 0.7620 - val_loss: 1.4074 - val_categorical_accuracy: 0.5675 - lr: 0.0100
# Epoch 19/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7339 - categorical_accuracy: 0.7614
# Epoch 19: val_loss did not improve from 0.71336
# 880/880 [==============================] - 513s 583ms/step - loss: 0.7339 - categorical_accuracy: 0.7614 - val_loss: 0.8167 - val_categorical_accuracy: 0.7293 - lr: 0.0100
# Epoch 20/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7422 - categorical_accuracy: 0.7600
# Epoch 20: val_loss did not improve from 0.71336
# 880/880 [==============================] - 472s 536ms/step - loss: 0.7422 - categorical_accuracy: 0.7600 - val_loss: 0.9150 - val_categorical_accuracy: 0.7071 - lr: 0.0100
# Epoch 21/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7301 - categorical_accuracy: 0.7671
# Epoch 21: val_loss did not improve from 0.71336
# 880/880 [==============================] - 468s 532ms/step - loss: 0.7301 - categorical_accuracy: 0.7671 - val_loss: 1.4052 - val_categorical_accuracy: 0.5796 - lr: 0.0100
# Epoch 22/200
# 880/880 [==============================] - ETA: 0s - loss: 0.7255 - categorical_accuracy: 0.7683
# Epoch 22: val_loss did not improve from 0.71336
# 880/880 [==============================] - 470s 534ms/step - loss: 0.7255 - categorical_accuracy: 0.7683 - val_loss: 0.7511 - val_categorical_accuracy: 0.7587 - lr: 0.0100
# Epoch 23/200
# 880/880 [==============================] - ETA: 0s - loss: 0.5855 - categorical_accuracy: 0.8081
# Epoch 23: val_loss improved from 0.71336 to 0.57957, saving model to modelsave.h5
# 880/880 [==============================] - 545s 619ms/step - loss: 0.5855 - categorical_accuracy: 0.8081 - val_loss: 0.5796 - val_categorical_accuracy: 0.8134 - lr: 0.0020
# Epoch 24/200
# 880/880 [==============================] - ETA: 0s - loss: 0.5424 - categorical_accuracy: 0.8243
# Epoch 24: val_loss improved from 0.57957 to 0.55106, saving model to modelsave.h5
# 880/880 [==============================] - 501s 569ms/step - loss: 0.5424 - categorical_accuracy: 0.8243 - val_loss: 0.5511 - val_categorical_accuracy: 0.8187 - lr: 0.0020
# Epoch 25/200
# 880/880 [==============================] - ETA: 0s - loss: 0.5377 - categorical_accuracy: 0.8250
# Epoch 25: val_loss improved from 0.55106 to 0.51910, saving model to modelsave.h5
# 880/880 [==============================] - 710s 806ms/step - loss: 0.5377 - categorical_accuracy: 0.8250 - val_loss: 0.5191 - val_categorical_accuracy: 0.8235 - lr: 0.0020
# Epoch 26/200
# 880/880 [==============================] - ETA: 0s - loss: 0.5330 - categorical_accuracy: 0.8274
# Epoch 26: val_loss improved from 0.51910 to 0.51732, saving model to modelsave.h5
# 880/880 [==============================] - 715s 813ms/step - loss: 0.5330 - categorical_accuracy: 0.8274 - val_loss: 0.5173 - val_categorical_accuracy: 0.8215 - lr: 0.0020
# Epoch 27/200
# 880/880 [==============================] - ETA: 0s - loss: 0.5262 - categorical_accuracy: 0.8299
# Epoch 27: val_loss did not improve from 0.51732
# 880/880 [==============================] - 479s 544ms/step - loss: 0.5262 - categorical_accuracy: 0.8299 - val_loss: 0.5446 - val_categorical_accuracy: 0.8131 - lr: 0.0020
# Epoch 28/200
# 880/880 [==============================] - ETA: 0s - loss: 0.5170 - categorical_accuracy: 0.8306
# Epoch 28: val_loss improved from 0.51732 to 0.50562, saving model to modelsave.h5
# 880/880 [==============================] - 552s 627ms/step - loss: 0.5170 - categorical_accuracy: 0.8306 - val_loss: 0.5056 - val_categorical_accuracy: 0.8337 - lr: 0.0020
# Epoch 29/200
# 880/880 [==============================] - ETA: 0s - loss: 0.5087 - categorical_accuracy: 0.8353
# Epoch 29: val_loss did not improve from 0.50562
# 880/880 [==============================] - 479s 544ms/step - loss: 0.5087 - categorical_accuracy: 0.8353 - val_loss: 0.5551 - val_categorical_accuracy: 0.8167 - lr: 0.0020
# Epoch 30/200
# 880/880 [==============================] - ETA: 0s - loss: 0.5084 - categorical_accuracy: 0.8355
# Epoch 30: val_loss did not improve from 0.50562
# 880/880 [==============================] - 481s 547ms/step - loss: 0.5084 - categorical_accuracy: 0.8355 - val_loss: 0.5077 - val_categorical_accuracy: 0.8292 - lr: 0.0020
# Epoch 31/200
# 880/880 [==============================] - ETA: 0s - loss: 0.5057 - categorical_accuracy: 0.8341
# Epoch 31: val_loss improved from 0.50562 to 0.49165, saving model to modelsave.h5
# 880/880 [==============================] - 615s 699ms/step - loss: 0.5057 - categorical_accuracy: 0.8341 - val_loss: 0.4916 - val_categorical_accuracy: 0.8356 - lr: 0.0020
# Epoch 32/200
# 880/880 [==============================] - ETA: 0s - loss: 0.5048 - categorical_accuracy: 0.8350
# Epoch 32: val_loss did not improve from 0.49165
# 880/880 [==============================] - 480s 546ms/step - loss: 0.5048 - categorical_accuracy: 0.8350 - val_loss: 0.5139 - val_categorical_accuracy: 0.8314 - lr: 0.0020
# Epoch 33/200
# 880/880 [==============================] - ETA: 0s - loss: 0.5012 - categorical_accuracy: 0.8340
# Epoch 33: val_loss did not improve from 0.49165
# 880/880 [==============================] - 481s 546ms/step - loss: 0.5012 - categorical_accuracy: 0.8340 - val_loss: 0.5398 - val_categorical_accuracy: 0.8201 - lr: 0.0020
# Epoch 34/200
# 880/880 [==============================] - ETA: 0s - loss: 0.4955 - categorical_accuracy: 0.8417
# Epoch 34: val_loss did not improve from 0.49165
# 880/880 [==============================] - 485s 551ms/step - loss: 0.4955 - categorical_accuracy: 0.8417 - val_loss: 0.5457 - val_categorical_accuracy: 0.8210 - lr: 0.0020
# Epoch 35/200
# 880/880 [==============================] - ETA: 0s - loss: 0.4897 - categorical_accuracy: 0.8392
# Epoch 35: val_loss did not improve from 0.49165
# 880/880 [==============================] - 486s 552ms/step - loss: 0.4897 - categorical_accuracy: 0.8392 - val_loss: 0.5729 - val_categorical_accuracy: 0.8097 - lr: 0.0020
# Epoch 36/200
# 880/880 [==============================] - ETA: 0s - loss: 0.4853 - categorical_accuracy: 0.8390
# Epoch 36: val_loss improved from 0.49165 to 0.48386, saving model to modelsave.h5
# 880/880 [==============================] - 688s 781ms/step - loss: 0.4853 - categorical_accuracy: 0.8390 - val_loss: 0.4839 - val_categorical_accuracy: 0.8345 - lr: 0.0020
# Epoch 37/200
# 880/880 [==============================] - ETA: 0s - loss: 0.4786 - categorical_accuracy: 0.8460
# Epoch 37: val_loss did not improve from 0.48386
# 880/880 [==============================] - 520s 591ms/step - loss: 0.4786 - categorical_accuracy: 0.8460 - val_loss: 0.5752 - val_categorical_accuracy: 0.8139 - lr: 0.0020
# Epoch 38/200
# 880/880 [==============================] - ETA: 0s - loss: 0.4811 - categorical_accuracy: 0.8428
# Epoch 38: val_loss did not improve from 0.48386
# 880/880 [==============================] - 482s 547ms/step - loss: 0.4811 - categorical_accuracy: 0.8428 - val_loss: 0.5566 - val_categorical_accuracy: 0.8122 - lr: 0.0020
# Epoch 39/200
# 880/880 [==============================] - ETA: 0s - loss: 0.4788 - categorical_accuracy: 0.8438
# Epoch 39: val_loss did not improve from 0.48386
# 880/880 [==============================] - 481s 546ms/step - loss: 0.4788 - categorical_accuracy: 0.8438 - val_loss: 0.5202 - val_categorical_accuracy: 0.8235 - lr: 0.0020
# Epoch 40/200
# 880/880 [==============================] - ETA: 0s - loss: 0.4816 - categorical_accuracy: 0.8401
# Epoch 40: val_loss did not improve from 0.48386
# 880/880 [==============================] - 484s 550ms/step - loss: 0.4816 - categorical_accuracy: 0.8401 - val_loss: 0.4953 - val_categorical_accuracy: 0.8269 - lr: 0.0020
# Epoch 41/200
# 880/880 [==============================] - ETA: 0s - loss: 0.4779 - categorical_accuracy: 0.8434
# Epoch 41: val_loss did not improve from 0.48386
# 880/880 [==============================] - 484s 550ms/step - loss: 0.4779 - categorical_accuracy: 0.8434 - val_loss: 0.4917 - val_categorical_accuracy: 0.8323 - lr: 0.0020
# Epoch 42/200
# 880/880 [==============================] - ETA: 0s - loss: 0.4739 - categorical_accuracy: 0.8495
# Epoch 42: val_loss did not improve from 0.48386
# 880/880 [==============================] - 521s 591ms/step - loss: 0.4739 - categorical_accuracy: 0.8495 - val_loss: 0.5425 - val_categorical_accuracy: 0.8182 - lr: 0.0020
# Epoch 43/200
# 309/880 [=========>....................] - ETA: 4:44 - loss: 0.4826 - categorical_accuracy: 0.8388

# %%
print(history_classification.history)

# %%
fig1 = plt.figure(num="model regularize", figsize=(8, 6))
ax1 = fig1.add_subplot(111)
ax1.plot(history_classification.history['categorical_accuracy'], label='train accuracy', color='b')
ax1.plot(history_classification.history['val_categorical_accuracy'], label='val accuracy', color='g')
ax1.legend(loc = 'upper center')
ax1.set_xlabel('epoch')
ax1.set_ylabel('accuracy');
ax2 = ax1.twinx()
ax2.plot(history_classification.history['loss'], label="train loss", color='r')
ax2.plot(history_classification.history['val_loss'], label="val loss", color='y')
ax2.legend(loc=2)
ax2.set_ylabel('loss');
ax2.legend(loc = 'lower center')
plt.show()
