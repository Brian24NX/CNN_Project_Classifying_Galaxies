# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential, Model
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, GlobalMaxPooling2D
from sklearn.utils import shuffle
from tensorflow.keras import utils
from tensorflow import concat
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %%
with h5py.File('Galaxy10_DECals.h5', 'r') as F:
    images = np.array(F['images'])#这一步是读取图片
    labels = np.array(F['ans'])#这一步是读取图片的标签
    
images = images.astype(np.float32)#这一步是将图片转为float32类型   

labels = utils.to_categorical(labels, 10)#这一步是使用one-hot编码，一个10个类
labels = labels.astype(np.float32)#这一步是图片将图片的标签转为float32类型

# %%
(images, labels) = shuffle(images, labels)#这一步是打乱图片和其标签的排列顺序

# %%
#classes是类对应的英文名字，是否正确对应未检查。
classes = ['Disturbed Galaxies','Merging Galaxies','Round Smooth Galaxies','In-between Round Smooth Galaxies','Cigar Shaped Smooth Galaxies','Barred Spiral Galaxies','Unbarred Tight Spiral Galaxies','Unbarred Loose Spiral Galaxies','Edge-on Galaxies without Bulge','Edge-on Galaxies with Bulge']
class_labels = {classes:i for classes, i in enumerate(classes)}#生成类别名字到标号的对应关系，是否正确对应未检查。
print(class_labels)
# Out:
# {0: 'Disturbed Galaxies', 1: 'Merging Galaxies', 2: 'Round Smooth Galaxies', 3: 'In-between Round Smooth Galaxies', 4: 'Cigar Shaped Smooth Galaxies', 5: 'Barred Spiral Galaxies', 6: 'Unbarred Tight Spiral Galaxies', 7: 'Unbarred Loose Spiral Galaxies', 8: 'Edge-on Galaxies without Bulge', 9: 'Edge-on Galaxies with Bulge'}

# %%
#显示图片及其类别
plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[i]/255.)
    plt.xlabel(class_labels[int(np.argwhere(labels[i]==1))])
plt.show()

# %%
#SeNet的特征
class SeBlock(Model):
    def __init__(self, planes):
        super(SeBlock, self).__init__()
        self.se = Sequential()
        self.se.add(GlobalAveragePooling2D(keepdims=True))
        self.se.add(Conv2D(planes,kernel_size=(1,1),strides=(1, 1),padding='same'))
        self.se.add(Activation('gelu'))
        self.se.add(Conv2D(planes,kernel_size=(1,1),strides=(1, 1),padding='same'))
        self.se.add(Activation('sigmoid'))
    def call(self, inputs):
        out = self.se(inputs)
        return out

# %%
#ResNet的特征
class BasicBlock(Model):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.basic = Sequential()
        self.basic.add(Conv2D(planes,kernel_size=(3,3),strides=(stride, stride),padding='same')) 
        self.basic.add(BatchNormalization())
        self.basic.add(Activation('gelu'))
        self.basic.add(Conv2D(planes,kernel_size=(3,3),strides=(1, 1),padding='same'))
        self.basic.add(BatchNormalization())
        self.se1 = SeBlock(planes=planes)
        self.shortcut = Sequential()
        if in_planes!=planes or stride!=1:
            self.shortcut.add(Conv2D(planes,kernel_size=(1,1),strides=(stride, stride),padding='same'))
            self.shortcut.add(BatchNormalization())
        self.a2 = Activation('gelu')
    def call(self, inputs):
        out = self.basic(inputs)
        w = self.se1(out)
        out = out * w
        residual=self.shortcut(inputs)
        out = self.a2(residual+out)
        return out

# %%
#DlaNet的特征
class Root(Model):
    def __init__(self, planes, kernel_size=1):
        super(Root, self).__init__()
        self.basic = Sequential()
        self.basic.add(Conv2D(planes,kernel_size=(kernel_size,kernel_size),strides=(1, 1),padding='same'))
        self.basic.add(BatchNormalization())
        self.basic.add(Activation('gelu'))
    def call(self, inputs):
        out = concat(inputs, axis=-1)
        out = self.basic(out)
        return out

# %%
#DlaNet的特征
class Tree(Model):
    def __init__(self, in_planes, planes, level=1, stride=1):
        super(Tree, self).__init__()
        self.level = level
        if level == 1:
            self.root = Root(planes)
            self.left_node = BasicBlock(in_planes, planes, stride=stride)
            self.right_node = BasicBlock(planes, planes, stride=1)
        else:
            self.root = Root(planes)
            self.subtrees={}
            for i in reversed(range(1, level)):
                if i==level-1:
                    subtree = Tree(in_planes, planes, level=i, stride=stride)
                else:
                    subtree = Tree(planes, planes, level=i, stride=stride)
                self.subtrees[f'level_{i}'] = subtree
            self.prev_root = BasicBlock(in_planes, planes, stride=stride)
            self.left_node = BasicBlock(planes, planes, stride=1)
            self.right_node = BasicBlock(planes, planes, stride=1)
    def call(self, inputs):
        out = inputs
        outs = [self.prev_root(out)] if self.level > 1 else []
        for i in reversed(range(1, self.level)):
            level_i = self.subtrees[f'level_{i}']
            out = level_i(out)
            outs.append(out)
        out = self.left_node(out)
        outs.append(out)
        out = self.right_node(out)
        outs.append(out)
        out = self.root(outs)
        return out

# %%
#该模型没有同池化操作下采样，处理SeNet生成权值w部分，使用激活函数包括sigmoid，tanh，gelu
class CNN_net(Model):
    def __init__(self, model):
        super(CNN_net, self).__init__()
        self.stem = Sequential()
        self.stem.add(Conv2D(16,kernel_size=(5,5),strides=(1, 1),padding='same'))#256
        self.stem.add(BatchNormalization())
        self.stem.add(Activation('gelu'))
        self.stem.add(Conv2D(32,kernel_size=(3,3),strides=(1, 1),padding='same'))#256
        self.stem.add(BatchNormalization())
        self.stem.add(Activation('gelu'))
        self.stem.add(Conv2D(32,kernel_size=(3,3),strides=(2, 2),padding='same'))#128
        self.stem.add(BatchNormalization())
        self.stem.add(Activation('gelu'))
        
        self.blocks = Sequential()
        self.blocks.add(Tree(32,  64, level=2, stride=1))##128
        self.blocks.add(Tree(64,  128, level=2, stride=2))#64
        self.blocks.add(Tree(128,  256, level=2, stride=2))#32
        self.blocks.add(Tree(256,  512, level=2, stride=2))#16
        self.blocks.add(Tree(512,  1024, level=2, stride=2))#8
        self.blocks.add(Tree(1024,  2048, level=2, stride=2))#4
        self.blocks.add(Conv2D(2048,kernel_size=(4,4),strides=(1, 1),padding='valid'))#1
        self.blocks.add(BatchNormalization())
        self.blocks.add(Activation('gelu'))
        
        self.fullconnected = Sequential()
        self.fullconnected.add(Flatten())
        self.fullconnected.add(Dense(1024, activation='linear'))
        self.fullconnected.add(BatchNormalization())
        self.fullconnected.add(Activation('tanh'))
        self.fullconnected.add(Dense(1024, activation='linear'))
        self.fullconnected.add(BatchNormalization())
        self.fullconnected.add(Activation('tanh'))
        self.fullconnected.add(Dense(1024, activation='linear'))
        self.fullconnected.add(BatchNormalization())
        self.fullconnected.add(Activation('tanh'))
        
        self.out = Sequential()
        if model=='regression':
            self.out.add(Dense(1, activation='linear'))
        if model=='classification':
            self.out.add(Dense(10, activation='softmax'))
        
    def call(self, inputs):
        out = self.stem(inputs)
        out = self.blocks(out)
        out = self.fullconnected(out)
        out = self.out(out)
        return out

# %%
model_classification = CNN_net(model='classification')#生成用于classification的模型
# Out:
# 2023-10-11 09:42:26.731931: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46871 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:1b:00.0, compute capability: 8.6

# %%
model_classification.build(input_shape=(None, 256, 256, 3))#定义模型的input_shape
model_classification.summary()#生成模型的总结
# Out:
# Model: "cnn_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 128, 128, 32)      15424
#
#  sequential_1 (Sequential)   (None, 1, 1, 2048)        615363584
#
#  sequential_104 (Sequential  (None, 1024)              4209664
#  )
#
#  sequential_105 (Sequential  (None, 10)                10250
#  )
#
# =================================================================
# Total params: 619598922 (2.31 GB)
# Trainable params: 619475626 (2.31 GB)
# Non-trainable params: 123296 (481.62 KB)
# _________________________________________________________________

# %%
#这里是使用SGDR的参数
#initial_learning_rate = 0.1
#first_decay_steps = 1000
#t_mul = 2.0
#m_mul = 1.0
#alpha = 0.0

# %%
#这里是使用SGDR编译模型
#checkpoint_save_path = r'saved_modle_classification'
#lr_reducer = tf.keras.optimizers.schedules.CosineDecayRestarts(initial_learning_rate, first_decay_steps, t_mul=2.0, m_mul=1.0, alpha=0.0)
#model_classification.compile(optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=lr_reducer,momentum=0.9,nesterov=True,weight_decay=5e-4),loss=tf.keras.losses.CategoricalCrossentropy(),metrics=tf.keras.metrics.CategoricalAccuracy())

# %%
#这里是使用AdamW编译模型，并用ReduceLROnPlateau调整训练中的学习率
model_classification.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=0.01),loss=tf.keras.losses.CategoricalCrossentropy(),metrics=tf.keras.metrics.CategoricalAccuracy())
lr_reducer = ReduceLROnPlateau(monitor='val_loss',factor=0.2,patience=10,mode='min',min_lr=1e-20)

# %%
checkpoint_save_path = 'modelsave_allmixup.h5'#这里是模型的路径
#model_classification.load_weights(filepath=checkpoint_save_path)#这里是加载模型

# %%
train_datagen = ImageDataGenerator(
    featurewise_center=True,#将输入数据的每个样本减去整个数据集的均值，使得数据的均值为0。这有助于使数据集的均值接近于零。
    featurewise_std_normalization=True,#将输入数据的每个样本除以整个数据集的标准差，以使数据的标准差为1。这有助于使数据的标准差接近于1。
    rotation_range=180,#在范围内随机旋转图像，以增加数据的多样性。此参数指定旋转范围为±180度，即任意角度的旋转。
    width_shift_range=0.2,#在水平方向随机平移图像。此参数指定允许图像水平平移的范围为图像宽度的20%。
    height_shift_range=0.2,#在垂直方向随机平移图像。此参数指定允许图像垂直平移的范围为图像高度的20%。
    horizontal_flip=True,#随机水平翻转图像。这可以增加数据的多样性和泛化能力。
    rescale=1/255.,#对输入图像进行缩放，将像素值从0-255缩放到0-1范围之间。这通常是在训练之前对图像进行预处理的常见步骤。
    validation_split=0.2,#指定验证集的比例。在此情况下，20% 的数据将用作验证集，而剩余的 80% 将用于训练。
)

train_datagen.fit(images)#调用 fit 方法来计算输入图像数据的统计信息，包括均值和标准差。这将使用整个数据集来计算这些统计信息，并将它们应用于后续的数据增强和预处理过程中。

# %%
def mixup(batch_x, batch_y, alpha):
    batch_size = len(batch_x)
    lam = np.random.beta(alpha, alpha, size=batch_size)

    index = np.random.permutation(batch_size)
    mixed_x = lam.reshape(batch_size, 1, 1, 1) * batch_x + (1 - lam.reshape(batch_size, 1, 1, 1)) * batch_x[index]
    mixed_y = lam.reshape(batch_size, 1) * batch_y + (1 - lam.reshape(batch_size, 1)) * batch_y[index]

    return mixed_x, mixed_y

# %%
def datagen_generator(images, labels, batch_size, alpha):
    generator = train_datagen.flow(images, labels, batch_size=batch_size,subset='training')
    while True:
        batch_x, batch_y = next(generator)#next(generator) 返回的是使用 train_datagen.flow 生成器生成的下一个批次的图像数据和对应的标签。
        mixed_x, mixed_y = mixup(batch_x, batch_y, alpha)#调用mixup方法生成训练数据与标签
        yield mixed_x, mixed_y#通过使用 yield 语句返回混合后的图像数据和标签，即 yield mixed_x, mixed_y。这样，datagen_generator 函数就变成了一个生成器函数，每次调用它时，都会生成一个新的批次的混合数据。

# %%
batch_size = 16#batch_size大小为16
alpha = 1#alpha为1，代表着beta分布中各个概率出现的可能性相同

# %%
#checkpointer的作用是在训练中保存模型
checkpointer = ModelCheckpoint(filepath=checkpoint_save_path,monitor='val_loss',verbose=1,save_best_only=True,save_weights_only=True)
history_classification = model_classification.fit(datagen_generator(images, labels, batch_size, alpha),
                                                    validation_data=train_datagen.flow(images, labels,batch_size=batch_size, subset='validation'),
                                                    steps_per_epoch=880,
                                                    epochs=200,
                                                    callbacks=[lr_reducer, checkpointer]#调整学习率和保存模型
                                                 )
# Out:
# Epoch 1/200
# 2023-10-11 09:44:58.996766: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8900
# 2023-10-11 09:45:01.064111: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-10-11 09:45:01.399642: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fab4cff8cb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-11 09:45:01.399674: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-10-11 09:45:01.404757: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-11 09:45:01.538122: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 880/880 [==============================] - ETA: 0s - loss: 2.6364 - categorical_accuracy: 0.1410
# Epoch 1: val_loss improved from inf to 2.22158, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 626s 610ms/step - loss: 2.6364 - categorical_accuracy: 0.1410 - val_loss: 2.2216 - val_categorical_accuracy: 0.1497 - lr: 0.0100
# Epoch 2/200
# 880/880 [==============================] - ETA: 0s - loss: 2.2202 - categorical_accuracy: 0.1578
# Epoch 2: val_loss improved from 2.22158 to 2.17977, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 542s 616ms/step - loss: 2.2202 - categorical_accuracy: 0.1578 - val_loss: 2.1798 - val_categorical_accuracy: 0.1565 - lr: 0.0100
# Epoch 3/200
# 880/880 [==============================] - ETA: 0s - loss: 2.1886 - categorical_accuracy: 0.1806
# Epoch 3: val_loss did not improve from 2.17977
# 880/880 [==============================] - 503s 571ms/step - loss: 2.1886 - categorical_accuracy: 0.1806 - val_loss: 2.2146 - val_categorical_accuracy: 0.1415 - lr: 0.0100
# Epoch 4/200
# 880/880 [==============================] - ETA: 0s - loss: 2.1572 - categorical_accuracy: 0.1971
# Epoch 4: val_loss improved from 2.17977 to 2.02982, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 533s 605ms/step - loss: 2.1572 - categorical_accuracy: 0.1971 - val_loss: 2.0298 - val_categorical_accuracy: 0.2348 - lr: 0.0100
# Epoch 5/200
# 880/880 [==============================] - ETA: 0s - loss: 2.1366 - categorical_accuracy: 0.2143
# Epoch 5: val_loss did not improve from 2.02982
# 880/880 [==============================] - 500s 568ms/step - loss: 2.1366 - categorical_accuracy: 0.2143 - val_loss: 2.2638 - val_categorical_accuracy: 0.1255 - lr: 0.0100
# Epoch 6/200
# 880/880 [==============================] - ETA: 0s - loss: 2.1170 - categorical_accuracy: 0.2172
# Epoch 6: val_loss improved from 2.02982 to 2.00803, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 533s 606ms/step - loss: 2.1170 - categorical_accuracy: 0.2172 - val_loss: 2.0080 - val_categorical_accuracy: 0.2098 - lr: 0.0100
# Epoch 7/200
# 880/880 [==============================] - ETA: 0s - loss: 2.1168 - categorical_accuracy: 0.2149
# Epoch 7: val_loss did not improve from 2.00803
# 880/880 [==============================] - 499s 567ms/step - loss: 2.1168 - categorical_accuracy: 0.2149 - val_loss: 2.3836 - val_categorical_accuracy: 0.1537 - lr: 0.0100
# Epoch 8/200
# 880/880 [==============================] - ETA: 0s - loss: 2.1383 - categorical_accuracy: 0.2057
# Epoch 8: val_loss did not improve from 2.00803
# 880/880 [==============================] - 499s 567ms/step - loss: 2.1383 - categorical_accuracy: 0.2057 - val_loss: 2.0166 - val_categorical_accuracy: 0.2650 - lr: 0.0100
# Epoch 9/200
# 880/880 [==============================] - ETA: 0s - loss: 2.0873 - categorical_accuracy: 0.2336
# Epoch 9: val_loss did not improve from 2.00803
# 880/880 [==============================] - 499s 567ms/step - loss: 2.0873 - categorical_accuracy: 0.2336 - val_loss: 2.3860 - val_categorical_accuracy: 0.1548 - lr: 0.0100
# Epoch 10/200
# 880/880 [==============================] - ETA: 0s - loss: 2.0624 - categorical_accuracy: 0.2520
# Epoch 10: val_loss improved from 2.00803 to 1.88026, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 530s 603ms/step - loss: 2.0624 - categorical_accuracy: 0.2520 - val_loss: 1.8803 - val_categorical_accuracy: 0.2735 - lr: 0.0100
# Epoch 11/200
# 880/880 [==============================] - ETA: 0s - loss: 2.0046 - categorical_accuracy: 0.2795
# Epoch 11: val_loss did not improve from 1.88026
# 880/880 [==============================] - 499s 567ms/step - loss: 2.0046 - categorical_accuracy: 0.2795 - val_loss: 1.9361 - val_categorical_accuracy: 0.3053 - lr: 0.0100
# Epoch 12/200
# 880/880 [==============================] - ETA: 0s - loss: 1.9648 - categorical_accuracy: 0.2984
# Epoch 12: val_loss improved from 1.88026 to 1.71417, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 531s 603ms/step - loss: 1.9648 - categorical_accuracy: 0.2984 - val_loss: 1.7142 - val_categorical_accuracy: 0.3583 - lr: 0.0100
# Epoch 13/200
# 880/880 [==============================] - ETA: 0s - loss: 1.9295 - categorical_accuracy: 0.3178
# Epoch 13: val_loss did not improve from 1.71417
# 880/880 [==============================] - 499s 567ms/step - loss: 1.9295 - categorical_accuracy: 0.3178 - val_loss: 1.8779 - val_categorical_accuracy: 0.2935 - lr: 0.0100
# Epoch 14/200
# 880/880 [==============================] - ETA: 0s - loss: 1.9067 - categorical_accuracy: 0.3253
# Epoch 14: val_loss improved from 1.71417 to 1.58524, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 529s 601ms/step - loss: 1.9067 - categorical_accuracy: 0.3253 - val_loss: 1.5852 - val_categorical_accuracy: 0.4220 - lr: 0.0100
# Epoch 15/200
# 880/880 [==============================] - ETA: 0s - loss: 1.8773 - categorical_accuracy: 0.3425
# Epoch 15: val_loss did not improve from 1.58524
# 880/880 [==============================] - 500s 568ms/step - loss: 1.8773 - categorical_accuracy: 0.3425 - val_loss: 1.8031 - val_categorical_accuracy: 0.3141 - lr: 0.0100
# Epoch 16/200
# 880/880 [==============================] - ETA: 0s - loss: 1.8551 - categorical_accuracy: 0.3580
# Epoch 16: val_loss did not improve from 1.58524
# 880/880 [==============================] - 499s 567ms/step - loss: 1.8551 - categorical_accuracy: 0.3580 - val_loss: 1.6148 - val_categorical_accuracy: 0.4220 - lr: 0.0100
# Epoch 17/200
# 880/880 [==============================] - ETA: 0s - loss: 1.8232 - categorical_accuracy: 0.3805
# Epoch 17: val_loss did not improve from 1.58524
# 880/880 [==============================] - 500s 568ms/step - loss: 1.8232 - categorical_accuracy: 0.3805 - val_loss: 2.5287 - val_categorical_accuracy: 0.2481 - lr: 0.0100
# Epoch 18/200
# 880/880 [==============================] - ETA: 0s - loss: 1.8018 - categorical_accuracy: 0.3975
# Epoch 18: val_loss did not improve from 1.58524
# 880/880 [==============================] - 501s 569ms/step - loss: 1.8018 - categorical_accuracy: 0.3975 - val_loss: 1.7826 - val_categorical_accuracy: 0.3547 - lr: 0.0100
# Epoch 19/200
# 880/880 [==============================] - ETA: 0s - loss: 1.7671 - categorical_accuracy: 0.4090
# Epoch 19: val_loss improved from 1.58524 to 1.55160, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 530s 603ms/step - loss: 1.7671 - categorical_accuracy: 0.4090 - val_loss: 1.5516 - val_categorical_accuracy: 0.4756 - lr: 0.0100
# Epoch 20/200
# 880/880 [==============================] - ETA: 0s - loss: 1.7283 - categorical_accuracy: 0.4343
# Epoch 20: val_loss did not improve from 1.55160
# 880/880 [==============================] - 498s 566ms/step - loss: 1.7283 - categorical_accuracy: 0.4343 - val_loss: 2.1099 - val_categorical_accuracy: 0.2281 - lr: 0.0100
# Epoch 21/200
# 880/880 [==============================] - ETA: 0s - loss: 1.7343 - categorical_accuracy: 0.4365
# Epoch 21: val_loss did not improve from 1.55160
# 880/880 [==============================] - 501s 569ms/step - loss: 1.7343 - categorical_accuracy: 0.4365 - val_loss: 1.7144 - val_categorical_accuracy: 0.4485 - lr: 0.0100
# Epoch 22/200
# 880/880 [==============================] - ETA: 0s - loss: 1.7182 - categorical_accuracy: 0.4449
# Epoch 22: val_loss did not improve from 1.55160
# 880/880 [==============================] - 501s 569ms/step - loss: 1.7182 - categorical_accuracy: 0.4449 - val_loss: 1.6741 - val_categorical_accuracy: 0.3860 - lr: 0.0100
# Epoch 23/200
# 880/880 [==============================] - ETA: 0s - loss: 1.7022 - categorical_accuracy: 0.4556
# Epoch 23: val_loss improved from 1.55160 to 1.39872, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 536s 610ms/step - loss: 1.7022 - categorical_accuracy: 0.4556 - val_loss: 1.3987 - val_categorical_accuracy: 0.5142 - lr: 0.0100
# Epoch 24/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6793 - categorical_accuracy: 0.4638
# Epoch 24: val_loss did not improve from 1.39872
# 880/880 [==============================] - 501s 570ms/step - loss: 1.6793 - categorical_accuracy: 0.4638 - val_loss: 1.5966 - val_categorical_accuracy: 0.4291 - lr: 0.0100
# Epoch 25/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6796 - categorical_accuracy: 0.4693
# Epoch 25: val_loss did not improve from 1.39872
# 880/880 [==============================] - 503s 572ms/step - loss: 1.6796 - categorical_accuracy: 0.4693 - val_loss: 1.5276 - val_categorical_accuracy: 0.4328 - lr: 0.0100
# Epoch 26/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6535 - categorical_accuracy: 0.4804
# Epoch 26: val_loss did not improve from 1.39872
# 880/880 [==============================] - 499s 568ms/step - loss: 1.6535 - categorical_accuracy: 0.4804 - val_loss: 1.5905 - val_categorical_accuracy: 0.4429 - lr: 0.0100
# Epoch 27/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6580 - categorical_accuracy: 0.4896
# Epoch 27: val_loss improved from 1.39872 to 1.35849, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 531s 603ms/step - loss: 1.6580 - categorical_accuracy: 0.4896 - val_loss: 1.3585 - val_categorical_accuracy: 0.5478 - lr: 0.0100
# Epoch 28/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6268 - categorical_accuracy: 0.5074
# Epoch 28: val_loss improved from 1.35849 to 1.27989, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 532s 605ms/step - loss: 1.6268 - categorical_accuracy: 0.5074 - val_loss: 1.2799 - val_categorical_accuracy: 0.5385 - lr: 0.0100
# Epoch 29/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6331 - categorical_accuracy: 0.5013
# Epoch 29: val_loss did not improve from 1.27989
# 880/880 [==============================] - 498s 566ms/step - loss: 1.6331 - categorical_accuracy: 0.5013 - val_loss: 1.4997 - val_categorical_accuracy: 0.4784 - lr: 0.0100
# Epoch 30/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6121 - categorical_accuracy: 0.5153
# Epoch 30: val_loss did not improve from 1.27989
# 880/880 [==============================] - 498s 566ms/step - loss: 1.6121 - categorical_accuracy: 0.5153 - val_loss: 1.5447 - val_categorical_accuracy: 0.4477 - lr: 0.0100
# Epoch 31/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6300 - categorical_accuracy: 0.5069
# Epoch 31: val_loss did not improve from 1.27989
# 880/880 [==============================] - 499s 567ms/step - loss: 1.6300 - categorical_accuracy: 0.5069 - val_loss: 1.4225 - val_categorical_accuracy: 0.5001 - lr: 0.0100
# Epoch 32/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6035 - categorical_accuracy: 0.5197
# Epoch 32: val_loss did not improve from 1.27989
# 880/880 [==============================] - 498s 566ms/step - loss: 1.6035 - categorical_accuracy: 0.5197 - val_loss: 1.7088 - val_categorical_accuracy: 0.3741 - lr: 0.0100
# Epoch 33/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6029 - categorical_accuracy: 0.5305
# Epoch 33: val_loss improved from 1.27989 to 1.26237, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 533s 606ms/step - loss: 1.6029 - categorical_accuracy: 0.5305 - val_loss: 1.2624 - val_categorical_accuracy: 0.5918 - lr: 0.0100
# Epoch 34/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6004 - categorical_accuracy: 0.5304
# Epoch 34: val_loss did not improve from 1.26237
# 880/880 [==============================] - 498s 566ms/step - loss: 1.6004 - categorical_accuracy: 0.5304 - val_loss: 1.6321 - val_categorical_accuracy: 0.3586 - lr: 0.0100
# Epoch 35/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6125 - categorical_accuracy: 0.5208
# Epoch 35: val_loss did not improve from 1.26237
# 880/880 [==============================] - 499s 567ms/step - loss: 1.6125 - categorical_accuracy: 0.5208 - val_loss: 1.3819 - val_categorical_accuracy: 0.4697 - lr: 0.0100
# Epoch 36/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5805 - categorical_accuracy: 0.5318
# Epoch 36: val_loss did not improve from 1.26237
# 880/880 [==============================] - 498s 566ms/step - loss: 1.5805 - categorical_accuracy: 0.5318 - val_loss: 1.4515 - val_categorical_accuracy: 0.5452 - lr: 0.0100
# Epoch 37/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5907 - categorical_accuracy: 0.5395
# Epoch 37: val_loss did not improve from 1.26237
# 880/880 [==============================] - 498s 566ms/step - loss: 1.5907 - categorical_accuracy: 0.5395 - val_loss: 1.7626 - val_categorical_accuracy: 0.3490 - lr: 0.0100
# Epoch 38/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5579 - categorical_accuracy: 0.5518
# Epoch 38: val_loss did not improve from 1.26237
# 880/880 [==============================] - 498s 566ms/step - loss: 1.5579 - categorical_accuracy: 0.5518 - val_loss: 2.0972 - val_categorical_accuracy: 0.2738 - lr: 0.0100
# Epoch 39/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5693 - categorical_accuracy: 0.5546
# Epoch 39: val_loss improved from 1.26237 to 1.08972, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 531s 604ms/step - loss: 1.5693 - categorical_accuracy: 0.5546 - val_loss: 1.0897 - val_categorical_accuracy: 0.6862 - lr: 0.0100
# Epoch 40/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5647 - categorical_accuracy: 0.5598
# Epoch 40: val_loss did not improve from 1.08972
# 880/880 [==============================] - 498s 566ms/step - loss: 1.5647 - categorical_accuracy: 0.5598 - val_loss: 1.1102 - val_categorical_accuracy: 0.6397 - lr: 0.0100
# Epoch 41/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5527 - categorical_accuracy: 0.5645
# Epoch 41: val_loss did not improve from 1.08972
# 880/880 [==============================] - 498s 566ms/step - loss: 1.5527 - categorical_accuracy: 0.5645 - val_loss: 1.5548 - val_categorical_accuracy: 0.4846 - lr: 0.0100
# Epoch 42/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5492 - categorical_accuracy: 0.5655
# Epoch 42: val_loss did not improve from 1.08972
# 880/880 [==============================] - 498s 566ms/step - loss: 1.5492 - categorical_accuracy: 0.5655 - val_loss: 1.1839 - val_categorical_accuracy: 0.6504 - lr: 0.0100
# Epoch 43/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5345 - categorical_accuracy: 0.5770
# Epoch 43: val_loss did not improve from 1.08972
# 880/880 [==============================] - 498s 566ms/step - loss: 1.5345 - categorical_accuracy: 0.5770 - val_loss: 1.3392 - val_categorical_accuracy: 0.5844 - lr: 0.0100
# Epoch 44/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5375 - categorical_accuracy: 0.5735
# Epoch 44: val_loss did not improve from 1.08972
# 880/880 [==============================] - 499s 567ms/step - loss: 1.5375 - categorical_accuracy: 0.5735 - val_loss: 1.3181 - val_categorical_accuracy: 0.5983 - lr: 0.0100
# Epoch 45/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5185 - categorical_accuracy: 0.5841
# Epoch 45: val_loss did not improve from 1.08972
# 880/880 [==============================] - 503s 572ms/step - loss: 1.5185 - categorical_accuracy: 0.5841 - val_loss: 1.2467 - val_categorical_accuracy: 0.6059 - lr: 0.0100
# Epoch 46/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5402 - categorical_accuracy: 0.5766
# Epoch 46: val_loss did not improve from 1.08972
# 880/880 [==============================] - 498s 566ms/step - loss: 1.5402 - categorical_accuracy: 0.5766 - val_loss: 1.4765 - val_categorical_accuracy: 0.4973 - lr: 0.0100
# Epoch 47/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5341 - categorical_accuracy: 0.5762
# Epoch 47: val_loss did not improve from 1.08972
# 880/880 [==============================] - 498s 567ms/step - loss: 1.5341 - categorical_accuracy: 0.5762 - val_loss: 1.2548 - val_categorical_accuracy: 0.6152 - lr: 0.0100
# Epoch 48/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5248 - categorical_accuracy: 0.5798
# Epoch 48: val_loss did not improve from 1.08972
# 880/880 [==============================] - 498s 566ms/step - loss: 1.5248 - categorical_accuracy: 0.5798 - val_loss: 1.2539 - val_categorical_accuracy: 0.5602 - lr: 0.0100
# Epoch 49/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5397 - categorical_accuracy: 0.5802
# Epoch 49: val_loss improved from 1.08972 to 1.07708, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 531s 603ms/step - loss: 1.5397 - categorical_accuracy: 0.5802 - val_loss: 1.0771 - val_categorical_accuracy: 0.6394 - lr: 0.0100
# Epoch 50/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5286 - categorical_accuracy: 0.5791
# Epoch 50: val_loss did not improve from 1.07708
# 880/880 [==============================] - 498s 566ms/step - loss: 1.5286 - categorical_accuracy: 0.5791 - val_loss: 1.3378 - val_categorical_accuracy: 0.6061 - lr: 0.0100
# Epoch 51/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5055 - categorical_accuracy: 0.5948
# Epoch 51: val_loss did not improve from 1.07708
# 880/880 [==============================] - 498s 566ms/step - loss: 1.5055 - categorical_accuracy: 0.5948 - val_loss: 1.1461 - val_categorical_accuracy: 0.6414 - lr: 0.0100
# Epoch 52/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4947 - categorical_accuracy: 0.5979
# Epoch 52: val_loss did not improve from 1.07708
# 880/880 [==============================] - 499s 567ms/step - loss: 1.4947 - categorical_accuracy: 0.5979 - val_loss: 1.1697 - val_categorical_accuracy: 0.5873 - lr: 0.0100
# Epoch 53/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5011 - categorical_accuracy: 0.5965
# Epoch 53: val_loss did not improve from 1.07708
# 880/880 [==============================] - 499s 567ms/step - loss: 1.5011 - categorical_accuracy: 0.5965 - val_loss: 1.5247 - val_categorical_accuracy: 0.4855 - lr: 0.0100
# Epoch 54/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4809 - categorical_accuracy: 0.6077
# Epoch 54: val_loss did not improve from 1.07708
# 880/880 [==============================] - 498s 566ms/step - loss: 1.4809 - categorical_accuracy: 0.6077 - val_loss: 1.4006 - val_categorical_accuracy: 0.5543 - lr: 0.0100
# Epoch 55/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4891 - categorical_accuracy: 0.5930
# Epoch 55: val_loss did not improve from 1.07708
# 880/880 [==============================] - 499s 567ms/step - loss: 1.4891 - categorical_accuracy: 0.5930 - val_loss: 1.7636 - val_categorical_accuracy: 0.4119 - lr: 0.0100
# Epoch 56/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4795 - categorical_accuracy: 0.6047
# Epoch 56: val_loss did not improve from 1.07708
# 880/880 [==============================] - 498s 566ms/step - loss: 1.4795 - categorical_accuracy: 0.6047 - val_loss: 1.1080 - val_categorical_accuracy: 0.6476 - lr: 0.0100
# Epoch 57/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4746 - categorical_accuracy: 0.6035
# Epoch 57: val_loss did not improve from 1.07708
# 880/880 [==============================] - 498s 566ms/step - loss: 1.4746 - categorical_accuracy: 0.6035 - val_loss: 1.3417 - val_categorical_accuracy: 0.5591 - lr: 0.0100
# Epoch 58/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4603 - categorical_accuracy: 0.6078
# Epoch 58: val_loss improved from 1.07708 to 1.02256, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 534s 607ms/step - loss: 1.4603 - categorical_accuracy: 0.6078 - val_loss: 1.0226 - val_categorical_accuracy: 0.6904 - lr: 0.0100
# Epoch 59/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4465 - categorical_accuracy: 0.6083
# Epoch 59: val_loss did not improve from 1.02256
# 880/880 [==============================] - 499s 568ms/step - loss: 1.4465 - categorical_accuracy: 0.6083 - val_loss: 1.1572 - val_categorical_accuracy: 0.6028 - lr: 0.0100
# Epoch 60/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4371 - categorical_accuracy: 0.6193
# Epoch 60: val_loss did not improve from 1.02256
# 880/880 [==============================] - 498s 567ms/step - loss: 1.4371 - categorical_accuracy: 0.6193 - val_loss: 1.3268 - val_categorical_accuracy: 0.5520 - lr: 0.0100
# Epoch 61/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4307 - categorical_accuracy: 0.6227
# Epoch 61: val_loss did not improve from 1.02256
# 880/880 [==============================] - 498s 566ms/step - loss: 1.4307 - categorical_accuracy: 0.6227 - val_loss: 1.2387 - val_categorical_accuracy: 0.6025 - lr: 0.0100
# Epoch 62/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4599 - categorical_accuracy: 0.6075
# Epoch 62: val_loss did not improve from 1.02256
# 880/880 [==============================] - 499s 567ms/step - loss: 1.4599 - categorical_accuracy: 0.6075 - val_loss: 1.0282 - val_categorical_accuracy: 0.6718 - lr: 0.0100
# Epoch 63/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4339 - categorical_accuracy: 0.6278
# Epoch 63: val_loss improved from 1.02256 to 0.96183, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 532s 604ms/step - loss: 1.4339 - categorical_accuracy: 0.6278 - val_loss: 0.9618 - val_categorical_accuracy: 0.7028 - lr: 0.0100
# Epoch 64/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4290 - categorical_accuracy: 0.6215
# Epoch 64: val_loss did not improve from 0.96183
# 880/880 [==============================] - 499s 567ms/step - loss: 1.4290 - categorical_accuracy: 0.6215 - val_loss: 1.2259 - val_categorical_accuracy: 0.6019 - lr: 0.0100
# Epoch 65/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4109 - categorical_accuracy: 0.6343
# Epoch 65: val_loss did not improve from 0.96183
# 880/880 [==============================] - 499s 567ms/step - loss: 1.4109 - categorical_accuracy: 0.6343 - val_loss: 1.2687 - val_categorical_accuracy: 0.5751 - lr: 0.0100
# Epoch 66/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4059 - categorical_accuracy: 0.6402
# Epoch 66: val_loss did not improve from 0.96183
# 880/880 [==============================] - 499s 567ms/step - loss: 1.4059 - categorical_accuracy: 0.6402 - val_loss: 0.9729 - val_categorical_accuracy: 0.7107 - lr: 0.0100
# Epoch 67/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4223 - categorical_accuracy: 0.6319
# Epoch 67: val_loss did not improve from 0.96183
# 880/880 [==============================] - 499s 567ms/step - loss: 1.4223 - categorical_accuracy: 0.6319 - val_loss: 1.0978 - val_categorical_accuracy: 0.6685 - lr: 0.0100
# Epoch 68/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4374 - categorical_accuracy: 0.6235
# Epoch 68: val_loss did not improve from 0.96183
# 880/880 [==============================] - 499s 567ms/step - loss: 1.4374 - categorical_accuracy: 0.6235 - val_loss: 1.0003 - val_categorical_accuracy: 0.7026 - lr: 0.0100
# Epoch 69/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4234 - categorical_accuracy: 0.6261
# Epoch 69: val_loss did not improve from 0.96183
# 880/880 [==============================] - 498s 566ms/step - loss: 1.4234 - categorical_accuracy: 0.6261 - val_loss: 1.2282 - val_categorical_accuracy: 0.6115 - lr: 0.0100
# Epoch 70/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4113 - categorical_accuracy: 0.6383
# Epoch 70: val_loss did not improve from 0.96183
# 880/880 [==============================] - 499s 567ms/step - loss: 1.4113 - categorical_accuracy: 0.6383 - val_loss: 1.2414 - val_categorical_accuracy: 0.6030 - lr: 0.0100
# Epoch 71/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4173 - categorical_accuracy: 0.6321
# Epoch 71: val_loss improved from 0.96183 to 0.95252, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 532s 604ms/step - loss: 1.4173 - categorical_accuracy: 0.6321 - val_loss: 0.9525 - val_categorical_accuracy: 0.7119 - lr: 0.0100
# Epoch 72/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3969 - categorical_accuracy: 0.6414
# Epoch 72: val_loss did not improve from 0.95252
# 880/880 [==============================] - 499s 567ms/step - loss: 1.3969 - categorical_accuracy: 0.6414 - val_loss: 1.0122 - val_categorical_accuracy: 0.6938 - lr: 0.0100
# Epoch 73/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4191 - categorical_accuracy: 0.6305
# Epoch 73: val_loss did not improve from 0.95252
# 880/880 [==============================] - 499s 567ms/step - loss: 1.4191 - categorical_accuracy: 0.6305 - val_loss: 1.0941 - val_categorical_accuracy: 0.6654 - lr: 0.0100
# Epoch 74/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3975 - categorical_accuracy: 0.6389
# Epoch 74: val_loss did not improve from 0.95252
# 880/880 [==============================] - 499s 567ms/step - loss: 1.3975 - categorical_accuracy: 0.6389 - val_loss: 1.4933 - val_categorical_accuracy: 0.4976 - lr: 0.0100
# Epoch 75/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3962 - categorical_accuracy: 0.6417
# Epoch 75: val_loss did not improve from 0.95252
# 880/880 [==============================] - 499s 567ms/step - loss: 1.3962 - categorical_accuracy: 0.6417 - val_loss: 1.2542 - val_categorical_accuracy: 0.5963 - lr: 0.0100
# Epoch 76/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3975 - categorical_accuracy: 0.6399
# Epoch 76: val_loss did not improve from 0.95252
# 880/880 [==============================] - 499s 567ms/step - loss: 1.3975 - categorical_accuracy: 0.6399 - val_loss: 1.4777 - val_categorical_accuracy: 0.5405 - lr: 0.0100
# Epoch 77/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3974 - categorical_accuracy: 0.6449
# Epoch 77: val_loss did not improve from 0.95252
# 880/880 [==============================] - 499s 567ms/step - loss: 1.3974 - categorical_accuracy: 0.6449 - val_loss: 1.1144 - val_categorical_accuracy: 0.6597 - lr: 0.0100
# Epoch 78/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4006 - categorical_accuracy: 0.6437
# Epoch 78: val_loss did not improve from 0.95252
# 880/880 [==============================] - 499s 567ms/step - loss: 1.4006 - categorical_accuracy: 0.6437 - val_loss: 1.1342 - val_categorical_accuracy: 0.6403 - lr: 0.0100
# Epoch 79/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3927 - categorical_accuracy: 0.6449
# Epoch 79: val_loss did not improve from 0.95252
# 880/880 [==============================] - 499s 567ms/step - loss: 1.3927 - categorical_accuracy: 0.6449 - val_loss: 1.0025 - val_categorical_accuracy: 0.6879 - lr: 0.0100
# Epoch 80/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3792 - categorical_accuracy: 0.6486
# Epoch 80: val_loss did not improve from 0.95252
# 880/880 [==============================] - 499s 567ms/step - loss: 1.3792 - categorical_accuracy: 0.6486 - val_loss: 1.0136 - val_categorical_accuracy: 0.6758 - lr: 0.0100
# Epoch 81/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3882 - categorical_accuracy: 0.6443
# Epoch 81: val_loss did not improve from 0.95252
# 880/880 [==============================] - 498s 566ms/step - loss: 1.3882 - categorical_accuracy: 0.6443 - val_loss: 1.1438 - val_categorical_accuracy: 0.6456 - lr: 0.0100
# Epoch 82/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2763 - categorical_accuracy: 0.6892
# Epoch 82: val_loss improved from 0.95252 to 0.65523, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 531s 604ms/step - loss: 1.2763 - categorical_accuracy: 0.6892 - val_loss: 0.6552 - val_categorical_accuracy: 0.8058 - lr: 0.0020
# Epoch 83/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2354 - categorical_accuracy: 0.7048
# Epoch 83: val_loss improved from 0.65523 to 0.65367, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 532s 605ms/step - loss: 1.2354 - categorical_accuracy: 0.7048 - val_loss: 0.6537 - val_categorical_accuracy: 0.8080 - lr: 0.0020
# Epoch 84/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2232 - categorical_accuracy: 0.7021
# Epoch 84: val_loss did not improve from 0.65367
# 880/880 [==============================] - 498s 566ms/step - loss: 1.2232 - categorical_accuracy: 0.7021 - val_loss: 0.6838 - val_categorical_accuracy: 0.7919 - lr: 0.0020
# Epoch 85/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2145 - categorical_accuracy: 0.7107
# Epoch 85: val_loss improved from 0.65367 to 0.64762, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 529s 601ms/step - loss: 1.2145 - categorical_accuracy: 0.7107 - val_loss: 0.6476 - val_categorical_accuracy: 0.8091 - lr: 0.0020
# Epoch 86/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2085 - categorical_accuracy: 0.7146
# Epoch 86: val_loss did not improve from 0.64762
# 880/880 [==============================] - 499s 567ms/step - loss: 1.2085 - categorical_accuracy: 0.7146 - val_loss: 0.7097 - val_categorical_accuracy: 0.7950 - lr: 0.0020
# Epoch 87/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2056 - categorical_accuracy: 0.7098
# Epoch 87: val_loss improved from 0.64762 to 0.64090, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 530s 602ms/step - loss: 1.2056 - categorical_accuracy: 0.7098 - val_loss: 0.6409 - val_categorical_accuracy: 0.8105 - lr: 0.0020
# Epoch 88/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2099 - categorical_accuracy: 0.7182
# Epoch 88: val_loss improved from 0.64090 to 0.63188, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 533s 606ms/step - loss: 1.2099 - categorical_accuracy: 0.7182 - val_loss: 0.6319 - val_categorical_accuracy: 0.8083 - lr: 0.0020
# Epoch 89/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1896 - categorical_accuracy: 0.7190
# Epoch 89: val_loss did not improve from 0.63188
# 880/880 [==============================] - 498s 566ms/step - loss: 1.1896 - categorical_accuracy: 0.7190 - val_loss: 0.6561 - val_categorical_accuracy: 0.8072 - lr: 0.0020
# Epoch 90/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1962 - categorical_accuracy: 0.7141
# Epoch 90: val_loss did not improve from 0.63188
# 880/880 [==============================] - 499s 567ms/step - loss: 1.1962 - categorical_accuracy: 0.7141 - val_loss: 0.6424 - val_categorical_accuracy: 0.8097 - lr: 0.0020
# Epoch 91/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1733 - categorical_accuracy: 0.7225
# Epoch 91: val_loss improved from 0.63188 to 0.62472, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 534s 607ms/step - loss: 1.1733 - categorical_accuracy: 0.7225 - val_loss: 0.6247 - val_categorical_accuracy: 0.8060 - lr: 0.0020
# Epoch 92/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1850 - categorical_accuracy: 0.7182
# Epoch 92: val_loss did not improve from 0.62472
# 880/880 [==============================] - 499s 567ms/step - loss: 1.1850 - categorical_accuracy: 0.7182 - val_loss: 0.6251 - val_categorical_accuracy: 0.8120 - lr: 0.0020
# Epoch 93/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1858 - categorical_accuracy: 0.7217
# Epoch 93: val_loss improved from 0.62472 to 0.60203, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 533s 605ms/step - loss: 1.1858 - categorical_accuracy: 0.7217 - val_loss: 0.6020 - val_categorical_accuracy: 0.8179 - lr: 0.0020
# Epoch 94/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1896 - categorical_accuracy: 0.7173
# Epoch 94: val_loss did not improve from 0.60203
# 880/880 [==============================] - 500s 568ms/step - loss: 1.1896 - categorical_accuracy: 0.7173 - val_loss: 0.6128 - val_categorical_accuracy: 0.8148 - lr: 0.0020
# Epoch 95/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1775 - categorical_accuracy: 0.7254
# Epoch 95: val_loss did not improve from 0.60203
# 880/880 [==============================] - 499s 567ms/step - loss: 1.1775 - categorical_accuracy: 0.7254 - val_loss: 0.6302 - val_categorical_accuracy: 0.8148 - lr: 0.0020
# Epoch 96/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1783 - categorical_accuracy: 0.7176
# Epoch 96: val_loss did not improve from 0.60203
# 880/880 [==============================] - 499s 567ms/step - loss: 1.1783 - categorical_accuracy: 0.7176 - val_loss: 0.7281 - val_categorical_accuracy: 0.7725 - lr: 0.0020
# Epoch 97/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1715 - categorical_accuracy: 0.7213
# Epoch 97: val_loss did not improve from 0.60203
# 880/880 [==============================] - 498s 566ms/step - loss: 1.1715 - categorical_accuracy: 0.7213 - val_loss: 0.6266 - val_categorical_accuracy: 0.8120 - lr: 0.0020
# Epoch 98/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1748 - categorical_accuracy: 0.7243
# Epoch 98: val_loss did not improve from 0.60203
# 880/880 [==============================] - 499s 567ms/step - loss: 1.1748 - categorical_accuracy: 0.7243 - val_loss: 0.6545 - val_categorical_accuracy: 0.8024 - lr: 0.0020
# Epoch 99/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1639 - categorical_accuracy: 0.7316
# Epoch 99: val_loss did not improve from 0.60203
# 880/880 [==============================] - 499s 567ms/step - loss: 1.1639 - categorical_accuracy: 0.7316 - val_loss: 0.6631 - val_categorical_accuracy: 0.8089 - lr: 0.0020
# Epoch 100/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1671 - categorical_accuracy: 0.7214
# Epoch 100: val_loss did not improve from 0.60203
# 880/880 [==============================] - 499s 567ms/step - loss: 1.1671 - categorical_accuracy: 0.7214 - val_loss: 0.6250 - val_categorical_accuracy: 0.8303 - lr: 0.0020
# Epoch 101/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1618 - categorical_accuracy: 0.7240
# Epoch 101: val_loss did not improve from 0.60203
# 880/880 [==============================] - 499s 567ms/step - loss: 1.1618 - categorical_accuracy: 0.7240 - val_loss: 0.6953 - val_categorical_accuracy: 0.7905 - lr: 0.0020
# Epoch 102/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1709 - categorical_accuracy: 0.7239
# Epoch 102: val_loss did not improve from 0.60203
# 880/880 [==============================] - 498s 566ms/step - loss: 1.1709 - categorical_accuracy: 0.7239 - val_loss: 0.6774 - val_categorical_accuracy: 0.7987 - lr: 0.0020
# Epoch 103/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1539 - categorical_accuracy: 0.7294
# Epoch 103: val_loss did not improve from 0.60203
# 880/880 [==============================] - 498s 566ms/step - loss: 1.1539 - categorical_accuracy: 0.7294 - val_loss: 0.6169 - val_categorical_accuracy: 0.8122 - lr: 0.0020
# Epoch 104/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1265 - categorical_accuracy: 0.7426
# Epoch 104: val_loss improved from 0.60203 to 0.55700, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 532s 605ms/step - loss: 1.1265 - categorical_accuracy: 0.7426 - val_loss: 0.5570 - val_categorical_accuracy: 0.8342 - lr: 4.0000e-04
# Epoch 105/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1175 - categorical_accuracy: 0.7425
# Epoch 105: val_loss improved from 0.55700 to 0.55658, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 535s 608ms/step - loss: 1.1175 - categorical_accuracy: 0.7425 - val_loss: 0.5566 - val_categorical_accuracy: 0.8283 - lr: 4.0000e-04
# Epoch 106/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1200 - categorical_accuracy: 0.7421
# Epoch 106: val_loss improved from 0.55658 to 0.55291, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 532s 604ms/step - loss: 1.1200 - categorical_accuracy: 0.7421 - val_loss: 0.5529 - val_categorical_accuracy: 0.8306 - lr: 4.0000e-04
# Epoch 107/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1149 - categorical_accuracy: 0.7490
# Epoch 107: val_loss improved from 0.55291 to 0.54851, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 529s 602ms/step - loss: 1.1149 - categorical_accuracy: 0.7490 - val_loss: 0.5485 - val_categorical_accuracy: 0.8359 - lr: 4.0000e-04
# Epoch 108/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1239 - categorical_accuracy: 0.7411
# Epoch 108: val_loss did not improve from 0.54851
# 880/880 [==============================] - 499s 567ms/step - loss: 1.1239 - categorical_accuracy: 0.7411 - val_loss: 0.5543 - val_categorical_accuracy: 0.8317 - lr: 4.0000e-04
# Epoch 109/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1147 - categorical_accuracy: 0.7448
# Epoch 109: val_loss improved from 0.54851 to 0.54128, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 530s 603ms/step - loss: 1.1147 - categorical_accuracy: 0.7448 - val_loss: 0.5413 - val_categorical_accuracy: 0.8393 - lr: 4.0000e-04
# Epoch 110/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1085 - categorical_accuracy: 0.7428
# Epoch 110: val_loss improved from 0.54128 to 0.53801, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 531s 604ms/step - loss: 1.1085 - categorical_accuracy: 0.7428 - val_loss: 0.5380 - val_categorical_accuracy: 0.8424 - lr: 4.0000e-04
# Epoch 111/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1100 - categorical_accuracy: 0.7459
# Epoch 111: val_loss did not improve from 0.53801
# 880/880 [==============================] - 499s 568ms/step - loss: 1.1100 - categorical_accuracy: 0.7459 - val_loss: 0.5426 - val_categorical_accuracy: 0.8314 - lr: 4.0000e-04
# Epoch 112/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1122 - categorical_accuracy: 0.7493
# Epoch 112: val_loss did not improve from 0.53801
# 880/880 [==============================] - 499s 567ms/step - loss: 1.1122 - categorical_accuracy: 0.7493 - val_loss: 0.5434 - val_categorical_accuracy: 0.8362 - lr: 4.0000e-04
# Epoch 113/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1111 - categorical_accuracy: 0.7490
# Epoch 113: val_loss did not improve from 0.53801
# 880/880 [==============================] - 497s 565ms/step - loss: 1.1111 - categorical_accuracy: 0.7490 - val_loss: 0.5553 - val_categorical_accuracy: 0.8390 - lr: 4.0000e-04
# Epoch 114/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1144 - categorical_accuracy: 0.7415
# Epoch 114: val_loss did not improve from 0.53801
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1144 - categorical_accuracy: 0.7415 - val_loss: 0.5415 - val_categorical_accuracy: 0.8376 - lr: 4.0000e-04
# Epoch 115/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1035 - categorical_accuracy: 0.7494
# Epoch 115: val_loss did not improve from 0.53801
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1035 - categorical_accuracy: 0.7494 - val_loss: 0.5416 - val_categorical_accuracy: 0.8317 - lr: 4.0000e-04
# Epoch 116/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1103 - categorical_accuracy: 0.7431
# Epoch 116: val_loss did not improve from 0.53801
# 880/880 [==============================] - 496s 563ms/step - loss: 1.1103 - categorical_accuracy: 0.7431 - val_loss: 0.5383 - val_categorical_accuracy: 0.8345 - lr: 4.0000e-04
# Epoch 117/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0937 - categorical_accuracy: 0.7515
# Epoch 117: val_loss did not improve from 0.53801
# 880/880 [==============================] - 496s 563ms/step - loss: 1.0937 - categorical_accuracy: 0.7515 - val_loss: 0.5405 - val_categorical_accuracy: 0.8317 - lr: 4.0000e-04
# Epoch 118/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1094 - categorical_accuracy: 0.7424
# Epoch 118: val_loss did not improve from 0.53801
# 880/880 [==============================] - 496s 563ms/step - loss: 1.1094 - categorical_accuracy: 0.7424 - val_loss: 0.5424 - val_categorical_accuracy: 0.8413 - lr: 4.0000e-04
# Epoch 119/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1049 - categorical_accuracy: 0.7485
# Epoch 119: val_loss did not improve from 0.53801
# 880/880 [==============================] - 497s 565ms/step - loss: 1.1049 - categorical_accuracy: 0.7485 - val_loss: 0.5435 - val_categorical_accuracy: 0.8418 - lr: 4.0000e-04
# Epoch 120/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1065 - categorical_accuracy: 0.7492
# Epoch 120: val_loss did not improve from 0.53801
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1065 - categorical_accuracy: 0.7492 - val_loss: 0.5441 - val_categorical_accuracy: 0.8370 - lr: 4.0000e-04
# Epoch 121/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1064 - categorical_accuracy: 0.7497
# Epoch 121: val_loss improved from 0.53801 to 0.52735, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 530s 602ms/step - loss: 1.1064 - categorical_accuracy: 0.7497 - val_loss: 0.5273 - val_categorical_accuracy: 0.8393 - lr: 8.0000e-05
# Epoch 122/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0855 - categorical_accuracy: 0.7496
# Epoch 122: val_loss improved from 0.52735 to 0.52468, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 544s 618ms/step - loss: 1.0855 - categorical_accuracy: 0.7496 - val_loss: 0.5247 - val_categorical_accuracy: 0.8421 - lr: 8.0000e-05
# Epoch 123/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0879 - categorical_accuracy: 0.7555
# Epoch 123: val_loss improved from 0.52468 to 0.52362, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 541s 615ms/step - loss: 1.0879 - categorical_accuracy: 0.7555 - val_loss: 0.5236 - val_categorical_accuracy: 0.8416 - lr: 8.0000e-05
# Epoch 124/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0929 - categorical_accuracy: 0.7527
# Epoch 124: val_loss did not improve from 0.52362
# 880/880 [==============================] - 499s 567ms/step - loss: 1.0929 - categorical_accuracy: 0.7527 - val_loss: 0.5263 - val_categorical_accuracy: 0.8393 - lr: 8.0000e-05
# Epoch 125/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0932 - categorical_accuracy: 0.7539
# Epoch 125: val_loss did not improve from 0.52362
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0932 - categorical_accuracy: 0.7539 - val_loss: 0.5293 - val_categorical_accuracy: 0.8424 - lr: 8.0000e-05
# Epoch 126/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0867 - categorical_accuracy: 0.7521
# Epoch 126: val_loss did not improve from 0.52362
# 880/880 [==============================] - 495s 563ms/step - loss: 1.0867 - categorical_accuracy: 0.7521 - val_loss: 0.5264 - val_categorical_accuracy: 0.8387 - lr: 8.0000e-05
# Epoch 127/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0788 - categorical_accuracy: 0.7564
# Epoch 127: val_loss improved from 0.52362 to 0.52076, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 537s 610ms/step - loss: 1.0788 - categorical_accuracy: 0.7564 - val_loss: 0.5208 - val_categorical_accuracy: 0.8418 - lr: 8.0000e-05
# Epoch 128/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0910 - categorical_accuracy: 0.7541
# Epoch 128: val_loss improved from 0.52076 to 0.52044, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 542s 616ms/step - loss: 1.0910 - categorical_accuracy: 0.7541 - val_loss: 0.5204 - val_categorical_accuracy: 0.8444 - lr: 8.0000e-05
# Epoch 129/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0884 - categorical_accuracy: 0.7530
# Epoch 129: val_loss did not improve from 0.52044
# 880/880 [==============================] - 496s 564ms/step - loss: 1.0884 - categorical_accuracy: 0.7530 - val_loss: 0.5256 - val_categorical_accuracy: 0.8435 - lr: 8.0000e-05
# Epoch 130/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0930 - categorical_accuracy: 0.7503
# Epoch 130: val_loss did not improve from 0.52044
# 880/880 [==============================] - 495s 563ms/step - loss: 1.0930 - categorical_accuracy: 0.7503 - val_loss: 0.5232 - val_categorical_accuracy: 0.8449 - lr: 8.0000e-05
# Epoch 131/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0907 - categorical_accuracy: 0.7551
# Epoch 131: val_loss improved from 0.52044 to 0.51794, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 542s 617ms/step - loss: 1.0907 - categorical_accuracy: 0.7551 - val_loss: 0.5179 - val_categorical_accuracy: 0.8447 - lr: 8.0000e-05
# Epoch 132/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0916 - categorical_accuracy: 0.7511
# Epoch 132: val_loss did not improve from 0.51794
# 880/880 [==============================] - 496s 563ms/step - loss: 1.0916 - categorical_accuracy: 0.7511 - val_loss: 0.5208 - val_categorical_accuracy: 0.8478 - lr: 8.0000e-05
# Epoch 133/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0915 - categorical_accuracy: 0.7541
# Epoch 133: val_loss did not improve from 0.51794
# 880/880 [==============================] - 497s 564ms/step - loss: 1.0915 - categorical_accuracy: 0.7541 - val_loss: 0.5195 - val_categorical_accuracy: 0.8489 - lr: 8.0000e-05
# Epoch 134/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0890 - categorical_accuracy: 0.7528
# Epoch 134: val_loss did not improve from 0.51794
# 880/880 [==============================] - 496s 563ms/step - loss: 1.0890 - categorical_accuracy: 0.7528 - val_loss: 0.5260 - val_categorical_accuracy: 0.8413 - lr: 8.0000e-05
# Epoch 135/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0821 - categorical_accuracy: 0.7518
# Epoch 135: val_loss did not improve from 0.51794
# 880/880 [==============================] - 496s 563ms/step - loss: 1.0821 - categorical_accuracy: 0.7518 - val_loss: 0.5237 - val_categorical_accuracy: 0.8444 - lr: 8.0000e-05
# Epoch 136/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0867 - categorical_accuracy: 0.7568
# Epoch 136: val_loss did not improve from 0.51794
# 880/880 [==============================] - 496s 564ms/step - loss: 1.0867 - categorical_accuracy: 0.7568 - val_loss: 0.5239 - val_categorical_accuracy: 0.8435 - lr: 8.0000e-05
# Epoch 137/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0882 - categorical_accuracy: 0.7491
# Epoch 137: val_loss did not improve from 0.51794
# 880/880 [==============================] - 496s 564ms/step - loss: 1.0882 - categorical_accuracy: 0.7491 - val_loss: 0.5302 - val_categorical_accuracy: 0.8418 - lr: 8.0000e-05
# Epoch 138/200
# ...
# Epoch 140: val_loss did not improve from 0.51794
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0765 - categorical_accuracy: 0.7578 - val_loss: 0.5255 - val_categorical_accuracy: 0.8418 - lr: 8.0000e-05
# Epoch 141/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0802 - categorical_accuracy: 0.7526
# Epoch 141: val_loss did not improve from 0.51794
# 880/880 [==============================] - 499s 567ms/step - loss: 1.0802 - categorical_accuracy: 0.7526 - val_loss: 0.5200 - val_categorical_accuracy: 0.8447 - lr: 8.0000e-05
# Epoch 142/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0846 - categorical_accuracy: 0.7544
# Epoch 142: val_loss did not improve from 0.51794
# 880/880 [==============================] - 500s 569ms/step - loss: 1.0846 - categorical_accuracy: 0.7544 - val_loss: 0.5200 - val_categorical_accuracy: 0.8495 - lr: 1.6000e-05
# Epoch 143/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0786 - categorical_accuracy: 0.7538
# Epoch 143: val_loss improved from 0.51794 to 0.51631, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 537s 611ms/step - loss: 1.0786 - categorical_accuracy: 0.7538 - val_loss: 0.5163 - val_categorical_accuracy: 0.8478 - lr: 1.6000e-05
# Epoch 144/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0851 - categorical_accuracy: 0.7542
# Epoch 144: val_loss did not improve from 0.51631
# 880/880 [==============================] - 500s 568ms/step - loss: 1.0851 - categorical_accuracy: 0.7542 - val_loss: 0.5216 - val_categorical_accuracy: 0.8418 - lr: 1.6000e-05
# Epoch 145/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0753 - categorical_accuracy: 0.7564
# Epoch 145: val_loss did not improve from 0.51631
# 880/880 [==============================] - 500s 569ms/step - loss: 1.0753 - categorical_accuracy: 0.7564 - val_loss: 0.5171 - val_categorical_accuracy: 0.8424 - lr: 1.6000e-05
# Epoch 146/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0809 - categorical_accuracy: 0.7552
# Epoch 146: val_loss did not improve from 0.51631
# 880/880 [==============================] - 501s 570ms/step - loss: 1.0809 - categorical_accuracy: 0.7552 - val_loss: 0.5175 - val_categorical_accuracy: 0.8475 - lr: 1.6000e-05
# Epoch 147/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0743 - categorical_accuracy: 0.7579
# Epoch 147: val_loss improved from 0.51631 to 0.51329, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 544s 618ms/step - loss: 1.0743 - categorical_accuracy: 0.7579 - val_loss: 0.5133 - val_categorical_accuracy: 0.8461 - lr: 1.6000e-05
# Epoch 148/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0861 - categorical_accuracy: 0.7621
# Epoch 148: val_loss did not improve from 0.51329
# 880/880 [==============================] - 500s 568ms/step - loss: 1.0861 - categorical_accuracy: 0.7621 - val_loss: 0.5213 - val_categorical_accuracy: 0.8455 - lr: 1.6000e-05
# Epoch 149/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0874 - categorical_accuracy: 0.7502
# Epoch 149: val_loss did not improve from 0.51329
# 880/880 [==============================] - 499s 567ms/step - loss: 1.0874 - categorical_accuracy: 0.7502 - val_loss: 0.5155 - val_categorical_accuracy: 0.8430 - lr: 1.6000e-05
# Epoch 150/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0802 - categorical_accuracy: 0.7586
# Epoch 150: val_loss did not improve from 0.51329
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0802 - categorical_accuracy: 0.7586 - val_loss: 0.5254 - val_categorical_accuracy: 0.8410 - lr: 1.6000e-05
# Epoch 151/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0798 - categorical_accuracy: 0.7576
# Epoch 151: val_loss did not improve from 0.51329
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0798 - categorical_accuracy: 0.7576 - val_loss: 0.5199 - val_categorical_accuracy: 0.8396 - lr: 1.6000e-05
# Epoch 152/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0751 - categorical_accuracy: 0.7639
# Epoch 152: val_loss did not improve from 0.51329
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0751 - categorical_accuracy: 0.7639 - val_loss: 0.5218 - val_categorical_accuracy: 0.8472 - lr: 1.6000e-05
# Epoch 153/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0823 - categorical_accuracy: 0.7561
# Epoch 153: val_loss did not improve from 0.51329
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0823 - categorical_accuracy: 0.7561 - val_loss: 0.5227 - val_categorical_accuracy: 0.8432 - lr: 1.6000e-05
# Epoch 154/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0921 - categorical_accuracy: 0.7519
# Epoch 154: val_loss did not improve from 0.51329
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0921 - categorical_accuracy: 0.7519 - val_loss: 0.5183 - val_categorical_accuracy: 0.8416 - lr: 1.6000e-05
# Epoch 155/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0840 - categorical_accuracy: 0.7526
# Epoch 155: val_loss did not improve from 0.51329
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0840 - categorical_accuracy: 0.7526 - val_loss: 0.5215 - val_categorical_accuracy: 0.8430 - lr: 1.6000e-05
# Epoch 156/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0777 - categorical_accuracy: 0.7534
# Epoch 156: val_loss did not improve from 0.51329
# 880/880 [==============================] - 499s 567ms/step - loss: 1.0777 - categorical_accuracy: 0.7534 - val_loss: 0.5157 - val_categorical_accuracy: 0.8458 - lr: 1.6000e-05
# Epoch 157/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0623 - categorical_accuracy: 0.7649
# Epoch 157: val_loss did not improve from 0.51329
# 880/880 [==============================] - 499s 567ms/step - loss: 1.0623 - categorical_accuracy: 0.7649 - val_loss: 0.5248 - val_categorical_accuracy: 0.8432 - lr: 1.6000e-05
# Epoch 158/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0819 - categorical_accuracy: 0.7541
# Epoch 158: val_loss improved from 0.51329 to 0.51226, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 538s 612ms/step - loss: 1.0819 - categorical_accuracy: 0.7541 - val_loss: 0.5123 - val_categorical_accuracy: 0.8489 - lr: 3.2000e-06
# Epoch 159/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0834 - categorical_accuracy: 0.7518
# Epoch 159: val_loss did not improve from 0.51226
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0834 - categorical_accuracy: 0.7518 - val_loss: 0.5196 - val_categorical_accuracy: 0.8424 - lr: 3.2000e-06
# Epoch 160/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0755 - categorical_accuracy: 0.7558
# Epoch 160: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0755 - categorical_accuracy: 0.7558 - val_loss: 0.5181 - val_categorical_accuracy: 0.8444 - lr: 3.2000e-06
# Epoch 161/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0765 - categorical_accuracy: 0.7568
# Epoch 161: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0765 - categorical_accuracy: 0.7568 - val_loss: 0.5202 - val_categorical_accuracy: 0.8410 - lr: 3.2000e-06
# Epoch 162/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0754 - categorical_accuracy: 0.7599
# Epoch 162: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0754 - categorical_accuracy: 0.7599 - val_loss: 0.5176 - val_categorical_accuracy: 0.8452 - lr: 3.2000e-06
# Epoch 163/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0864 - categorical_accuracy: 0.7551
# Epoch 163: val_loss did not improve from 0.51226
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0864 - categorical_accuracy: 0.7551 - val_loss: 0.5231 - val_categorical_accuracy: 0.8421 - lr: 3.2000e-06
# Epoch 164/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0867 - categorical_accuracy: 0.7519
# Epoch 164: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0867 - categorical_accuracy: 0.7519 - val_loss: 0.5170 - val_categorical_accuracy: 0.8540 - lr: 3.2000e-06
# Epoch 165/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0773 - categorical_accuracy: 0.7566
# Epoch 165: val_loss did not improve from 0.51226
# 880/880 [==============================] - 499s 568ms/step - loss: 1.0773 - categorical_accuracy: 0.7566 - val_loss: 0.5203 - val_categorical_accuracy: 0.8421 - lr: 3.2000e-06
# Epoch 166/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0842 - categorical_accuracy: 0.7531
# Epoch 166: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0842 - categorical_accuracy: 0.7531 - val_loss: 0.5208 - val_categorical_accuracy: 0.8424 - lr: 3.2000e-06
# Epoch 167/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0781 - categorical_accuracy: 0.7553
# Epoch 167: val_loss did not improve from 0.51226
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0781 - categorical_accuracy: 0.7553 - val_loss: 0.5183 - val_categorical_accuracy: 0.8444 - lr: 3.2000e-06
# Epoch 168/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0877 - categorical_accuracy: 0.7503
# Epoch 168: val_loss did not improve from 0.51226
# 880/880 [==============================] - 499s 567ms/step - loss: 1.0877 - categorical_accuracy: 0.7503 - val_loss: 0.5180 - val_categorical_accuracy: 0.8396 - lr: 3.2000e-06
# Epoch 169/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0738 - categorical_accuracy: 0.7553
# Epoch 169: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0738 - categorical_accuracy: 0.7553 - val_loss: 0.5152 - val_categorical_accuracy: 0.8469 - lr: 6.4000e-07
# Epoch 170/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0875 - categorical_accuracy: 0.7484
# Epoch 170: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0875 - categorical_accuracy: 0.7484 - val_loss: 0.5195 - val_categorical_accuracy: 0.8438 - lr: 6.4000e-07
# Epoch 171/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0681 - categorical_accuracy: 0.7578
# Epoch 171: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0681 - categorical_accuracy: 0.7578 - val_loss: 0.5167 - val_categorical_accuracy: 0.8466 - lr: 6.4000e-07
# Epoch 172/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0843 - categorical_accuracy: 0.7565
# Epoch 172: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0843 - categorical_accuracy: 0.7565 - val_loss: 0.5147 - val_categorical_accuracy: 0.8441 - lr: 6.4000e-07
# Epoch 173/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0888 - categorical_accuracy: 0.7527
# Epoch 173: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0888 - categorical_accuracy: 0.7527 - val_loss: 0.5237 - val_categorical_accuracy: 0.8390 - lr: 6.4000e-07
# Epoch 174/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0770 - categorical_accuracy: 0.7559
# Epoch 174: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0770 - categorical_accuracy: 0.7559 - val_loss: 0.5174 - val_categorical_accuracy: 0.8410 - lr: 6.4000e-07
# Epoch 175/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0855 - categorical_accuracy: 0.7552
# Epoch 175: val_loss did not improve from 0.51226
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0855 - categorical_accuracy: 0.7552 - val_loss: 0.5198 - val_categorical_accuracy: 0.8447 - lr: 6.4000e-07
# Epoch 176/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0732 - categorical_accuracy: 0.7578
# Epoch 176: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0732 - categorical_accuracy: 0.7578 - val_loss: 0.5239 - val_categorical_accuracy: 0.8478 - lr: 6.4000e-07
# Epoch 177/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0778 - categorical_accuracy: 0.7558
# Epoch 177: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0778 - categorical_accuracy: 0.7558 - val_loss: 0.5151 - val_categorical_accuracy: 0.8497 - lr: 6.4000e-07
# Epoch 178/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0793 - categorical_accuracy: 0.7568
# Epoch 178: val_loss did not improve from 0.51226
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0793 - categorical_accuracy: 0.7568 - val_loss: 0.5128 - val_categorical_accuracy: 0.8483 - lr: 6.4000e-07
# Epoch 179/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0860 - categorical_accuracy: 0.7536
# Epoch 179: val_loss did not improve from 0.51226
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0860 - categorical_accuracy: 0.7536 - val_loss: 0.5178 - val_categorical_accuracy: 0.8461 - lr: 1.2800e-07
# Epoch 180/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0952 - categorical_accuracy: 0.7495
# Epoch 180: val_loss did not improve from 0.51226
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0952 - categorical_accuracy: 0.7495 - val_loss: 0.5166 - val_categorical_accuracy: 0.8455 - lr: 1.2800e-07
# Epoch 181/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0840 - categorical_accuracy: 0.7519
# Epoch 181: val_loss improved from 0.51226 to 0.51181, saving model to modelsave_allmixup.h5
# 880/880 [==============================] - 533s 606ms/step - loss: 1.0840 - categorical_accuracy: 0.7519 - val_loss: 0.5118 - val_categorical_accuracy: 0.8458 - lr: 1.2800e-07
# Epoch 182/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0770 - categorical_accuracy: 0.7579
# Epoch 182: val_loss did not improve from 0.51181
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0770 - categorical_accuracy: 0.7579 - val_loss: 0.5151 - val_categorical_accuracy: 0.8404 - lr: 1.2800e-07
# Epoch 183/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0763 - categorical_accuracy: 0.7580
# Epoch 183: val_loss did not improve from 0.51181
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0763 - categorical_accuracy: 0.7580 - val_loss: 0.5187 - val_categorical_accuracy: 0.8449 - lr: 1.2800e-07
# Epoch 184/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0899 - categorical_accuracy: 0.7519
# Epoch 184: val_loss did not improve from 0.51181
# 880/880 [==============================] - 498s 566ms/step - loss: 1.0899 - categorical_accuracy: 0.7519 - val_loss: 0.5172 - val_categorical_accuracy: 0.8455 - lr: 1.2800e-07
# Epoch 185/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0817 - categorical_accuracy: 0.7571
# Epoch 185: val_loss did not improve from 0.51181
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0817 - categorical_accuracy: 0.7571 - val_loss: 0.5177 - val_categorical_accuracy: 0.8478 - lr: 1.2800e-07
# Epoch 186/200
# 880/880 [==============================] - ETA: 0s - loss: 1.0808 - categorical_accuracy: 0.7508
# Epoch 186: val_loss did not improve from 0.51181
# 880/880 [==============================] - 497s 565ms/step - loss: 1.0808 - categorical_accuracy: 0.7508 - val_loss: 0.5211 - val_categorical_accuracy: 0.8447 - lr: 1.2800e-07
# Epoch 187/200
# 535/880 [=================>............] - ETA: 2:57 - loss: 1.0735 - categorical_accuracy: 0.7541

# %%
print(history_classification.history)

# %%
fig1 = plt.figure(num="model regularize", figsize=(8, 6))
ax1 = fig1.add_subplot(111)
ax1.plot(history_classification.history['categorical_accuracy'], label='train accuracy', color='b')
ax1.plot(history_classification.history['val_categorical_accuracy'], label='val accuracy', color='g')
ax1.legend(loc = 'upper center')
ax1.set_xlabel('epoch')
ax1.set_ylabel('accuracy');
ax2 = ax1.twinx()
ax2.plot(history_classification.history['loss'], label="train loss", color='r')
ax2.plot(history_classification.history['val_loss'], label="val loss", color='y')
ax2.legend(loc=2)
ax2.set_ylabel('loss');
ax2.legend(loc = 'lower center')
plt.show()
