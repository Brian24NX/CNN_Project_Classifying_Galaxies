# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential, Model
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, GlobalMaxPooling2D
from sklearn.utils import shuffle
from tensorflow.keras import utils
from tensorflow import concat
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
# Out:
# 2023-10-10 03:17:13.541772: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-10 03:17:14.331157: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
with h5py.File('Galaxy10_DECals.h5', 'r') as F:
    images = np.array(F['images'])#这一步是读取图片
    labels = np.array(F['ans'])#这一步是读取图片的标签
    
images = images.astype(np.float32)#这一步是将图片转为float32类型   

labels = utils.to_categorical(labels, 10)#这一步是使用one-hot编码，一个10个类
labels = labels.astype(np.float32)#这一步是图片将图片的标签转为float32类型

# %%
(images, labels) = shuffle(images, labels)#这一步是打乱图片和其标签的排列顺序

# %%
#classes是类对应的英文名字，是否正确对应未检查。
classes = ['Disturbed Galaxies','Merging Galaxies','Round Smooth Galaxies','In-between Round Smooth Galaxies','Cigar Shaped Smooth Galaxies','Barred Spiral Galaxies','Unbarred Tight Spiral Galaxies','Unbarred Loose Spiral Galaxies','Edge-on Galaxies without Bulge','Edge-on Galaxies with Bulge']
class_labels = {classes:i for classes, i in enumerate(classes)}#生成类别名字到标号的对应关系，是否正确对应未检查。
print(class_labels)
# Out:
# {0: 'Disturbed Galaxies', 1: 'Merging Galaxies', 2: 'Round Smooth Galaxies', 3: 'In-between Round Smooth Galaxies', 4: 'Cigar Shaped Smooth Galaxies', 5: 'Barred Spiral Galaxies', 6: 'Unbarred Tight Spiral Galaxies', 7: 'Unbarred Loose Spiral Galaxies', 8: 'Edge-on Galaxies without Bulge', 9: 'Edge-on Galaxies with Bulge'}

# %%
#显示图片及其类别
plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[i]/255.)
    plt.xlabel(class_labels[int(np.argwhere(labels[i]==1))])
plt.show()

# %%
#SeNet的特征
class SeBlock(Model):
    def __init__(self, planes):
        super(SeBlock, self).__init__()
        self.se = Sequential()
        self.se.add(GlobalAveragePooling2D(keepdims=True))
        self.se.add(Conv2D(planes,kernel_size=(1,1),strides=(1, 1),padding='same'))
        self.se.add(Activation('gelu'))
        self.se.add(Conv2D(planes,kernel_size=(1,1),strides=(1, 1),padding='same'))
        self.se.add(Activation('sigmoid'))
    def call(self, inputs):
        out = self.se(inputs)
        return out

# %%
#ResNet的特征
class BasicBlock(Model):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.basic = Sequential()
        self.basic.add(Conv2D(planes,kernel_size=(3,3),strides=(stride, stride),padding='same')) 
        self.basic.add(BatchNormalization())
        self.basic.add(Activation('gelu'))
        self.basic.add(Conv2D(planes,kernel_size=(3,3),strides=(1, 1),padding='same'))
        self.basic.add(BatchNormalization())
        self.se1 = SeBlock(planes=planes)
        self.shortcut = Sequential()
        if in_planes!=planes or stride!=1:
            self.shortcut.add(Conv2D(planes,kernel_size=(1,1),strides=(stride, stride),padding='same'))
            self.shortcut.add(BatchNormalization())
        self.a2 = Activation('gelu')
    def call(self, inputs):
        out = self.basic(inputs)
        w = self.se1(out)
        out = out * w
        residual=self.shortcut(inputs)
        out = self.a2(residual+out)
        return out

# %%
#DlaNet的特征
class Root(Model):
    def __init__(self, planes, kernel_size=1):
        super(Root, self).__init__()
        self.basic = Sequential()
        self.basic.add(Conv2D(planes,kernel_size=(kernel_size,kernel_size),strides=(1, 1),padding='same'))
        self.basic.add(BatchNormalization())
        self.basic.add(Activation('gelu'))
    def call(self, inputs):
        out = concat(inputs, axis=-1)
        out = self.basic(out)
        return out

# %%
#DlaNet的特征
class Tree(Model):
    def __init__(self, in_planes, planes, level=1, stride=1):
        super(Tree, self).__init__()
        self.level = level
        if level == 1:
            self.root = Root(planes)
            self.left_node = BasicBlock(in_planes, planes, stride=stride)
            self.right_node = BasicBlock(planes, planes, stride=1)
        else:
            self.root = Root(planes)
            self.subtrees={}
            for i in reversed(range(1, level)):
                if i==level-1:
                    subtree = Tree(in_planes, planes, level=i, stride=stride)
                else:
                    subtree = Tree(planes, planes, level=i, stride=stride)
                self.subtrees[f'level_{i}'] = subtree
            self.prev_root = BasicBlock(in_planes, planes, stride=stride)
            self.left_node = BasicBlock(planes, planes, stride=1)
            self.right_node = BasicBlock(planes, planes, stride=1)
    def call(self, inputs):
        out = inputs
        outs = [self.prev_root(out)] if self.level > 1 else []
        for i in reversed(range(1, self.level)):
            level_i = self.subtrees[f'level_{i}']
            out = level_i(out)
            outs.append(out)
        out = self.left_node(out)
        outs.append(out)
        out = self.right_node(out)
        outs.append(out)
        out = self.root(outs)
        return out

# %%
#该模型没有同池化操作下采样，处理SeNet生成权值w部分，使用激活函数包括sigmoid，tanh，gelu
class CNN_net(Model):
    def __init__(self, model):
        super(CNN_net, self).__init__()
        self.stem = Sequential()
        self.stem.add(Conv2D(16,kernel_size=(5,5),strides=(1, 1),padding='same'))#256
        self.stem.add(BatchNormalization())
        self.stem.add(Activation('gelu'))
        self.stem.add(Conv2D(32,kernel_size=(3,3),strides=(1, 1),padding='same'))#256
        self.stem.add(BatchNormalization())
        self.stem.add(Activation('gelu'))
        self.stem.add(Conv2D(32,kernel_size=(3,3),strides=(2, 2),padding='same'))#128
        self.stem.add(BatchNormalization())
        self.stem.add(Activation('gelu'))
        
        self.blocks = Sequential()
        self.blocks.add(Tree(32,  64, level=2, stride=1))##128
        self.blocks.add(Tree(64,  128, level=2, stride=2))#64
        self.blocks.add(Tree(128,  256, level=2, stride=2))#32
        self.blocks.add(Tree(256,  512, level=2, stride=2))#16
        self.blocks.add(Tree(512,  1024, level=2, stride=2))#8
        self.blocks.add(Tree(1024,  2048, level=2, stride=2))#4
        self.blocks.add(Conv2D(2048,kernel_size=(4,4),strides=(1, 1),padding='valid'))#1
        self.blocks.add(BatchNormalization())
        self.blocks.add(Activation('gelu'))
        
        self.fullconnected = Sequential()
        self.fullconnected.add(Flatten())
        self.fullconnected.add(Dense(1024, activation='linear'))
        self.fullconnected.add(BatchNormalization())
        self.fullconnected.add(Activation('tanh'))
        self.fullconnected.add(Dense(1024, activation='linear'))
        self.fullconnected.add(BatchNormalization())
        self.fullconnected.add(Activation('tanh'))
        self.fullconnected.add(Dense(1024, activation='linear'))
        self.fullconnected.add(BatchNormalization())
        self.fullconnected.add(Activation('tanh'))
        
        self.out = Sequential()
        if model=='regression':
            self.out.add(Dense(1, activation='linear'))
        if model=='classification':
            self.out.add(Dense(10, activation='softmax'))
        
    def call(self, inputs):
        out = self.stem(inputs)
        out = self.blocks(out)
        out = self.fullconnected(out)
        out = self.out(out)
        return out

# %%
model_classification = CNN_net(model='classification')#生成用于classification的模型
# Out:
# 2023-10-10 03:18:12.979505: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46871 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:1b:00.0, compute capability: 8.6

# %%
model_classification.build(input_shape=(None, 256, 256, 3))#定义模型的input_shape
model_classification.summary()#生成模型的总结
# Out:
# Model: "cnn_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 128, 128, 32)      15424
#
#  sequential_1 (Sequential)   (None, 1, 1, 2048)        615363584
#
#  sequential_104 (Sequential  (None, 1024)              4209664
#  )
#
#  sequential_105 (Sequential  (None, 10)                10250
#  )
#
# =================================================================
# Total params: 619598922 (2.31 GB)
# Trainable params: 619475626 (2.31 GB)
# Non-trainable params: 123296 (481.62 KB)
# _________________________________________________________________

# %%
#这里是使用SGDR的参数
#initial_learning_rate = 0.1
#first_decay_steps = 1000
#t_mul = 2.0
#m_mul = 1.0
#alpha = 0.0

# %%
#这里是使用SGDR编译模型
#checkpoint_save_path = r'saved_modle_classification'
#lr_reducer = tf.keras.optimizers.schedules.CosineDecayRestarts(initial_learning_rate, first_decay_steps, t_mul=2.0, m_mul=1.0, alpha=0.0)
#model_classification.compile(optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=lr_reducer,momentum=0.9,nesterov=True,weight_decay=5e-4),loss=tf.keras.losses.CategoricalCrossentropy(),metrics=tf.keras.metrics.CategoricalAccuracy())

# %%
#这里是使用AdamW编译模型，并用ReduceLROnPlateau调整训练中的学习率
model_classification.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=0.01),loss=tf.keras.losses.CategoricalCrossentropy(),metrics=tf.keras.metrics.CategoricalAccuracy())
lr_reducer = ReduceLROnPlateau(monitor='val_loss',factor=0.2,patience=10,mode='min',min_lr=1e-20)

# %%
checkpoint_save_path = 'modelsave.h5'#这里是模型的路径
model_classification.load_weights(filepath=checkpoint_save_path)#这里是加载模型

# %%
train_datagen = ImageDataGenerator(
    featurewise_center=True,#将输入数据的每个样本减去整个数据集的均值，使得数据的均值为0。这有助于使数据集的均值接近于零。
    featurewise_std_normalization=True,#将输入数据的每个样本除以整个数据集的标准差，以使数据的标准差为1。这有助于使数据的标准差接近于1。
    rotation_range=180,#在范围内随机旋转图像，以增加数据的多样性。此参数指定旋转范围为±180度，即任意角度的旋转。
    width_shift_range=0.2,#在水平方向随机平移图像。此参数指定允许图像水平平移的范围为图像宽度的20%。
    height_shift_range=0.2,#在垂直方向随机平移图像。此参数指定允许图像垂直平移的范围为图像高度的20%。
    horizontal_flip=True,#随机水平翻转图像。这可以增加数据的多样性和泛化能力。
    rescale=1/255.,#对输入图像进行缩放，将像素值从0-255缩放到0-1范围之间。这通常是在训练之前对图像进行预处理的常见步骤。
    validation_split=0.2,#指定验证集的比例。在此情况下，20% 的数据将用作验证集，而剩余的 80% 将用于训练。
)

train_datagen.fit(images)#调用 fit 方法来计算输入图像数据的统计信息，包括均值和标准差。这将使用整个数据集来计算这些统计信息，并将它们应用于后续的数据增强和预处理过程中。

# %%
def mixup(batch_x, batch_y, alpha):
    batch_size = len(batch_x)
    lam = np.random.beta(alpha, alpha, size=batch_size)

    index = np.random.permutation(batch_size)
    mixed_x = lam.reshape(batch_size, 1, 1, 1) * batch_x + (1 - lam.reshape(batch_size, 1, 1, 1)) * batch_x[index]
    mixed_y = lam.reshape(batch_size, 1) * batch_y + (1 - lam.reshape(batch_size, 1)) * batch_y[index]

    return mixed_x, mixed_y

# %%
def datagen_generator(images, labels, batch_size, alpha):
    generator = train_datagen.flow(images, labels, batch_size=batch_size,subset='training')
    while True:
        batch_x, batch_y = next(generator)#next(generator) 返回的是使用 train_datagen.flow 生成器生成的下一个批次的图像数据和对应的标签。
        mixed_x, mixed_y = mixup(batch_x, batch_y, alpha)#调用mixup方法生成训练数据与标签
        yield mixed_x, mixed_y#通过使用 yield 语句返回混合后的图像数据和标签，即 yield mixed_x, mixed_y。这样，datagen_generator 函数就变成了一个生成器函数，每次调用它时，都会生成一个新的批次的混合数据。

# %%
batch_size = 16#batch_size大小为16
alpha = 1#alpha为1，代表着beta分布中各个概率出现的可能性相同

# %%
#checkpointer的作用是在训练中保存模型
checkpointer = ModelCheckpoint(filepath=checkpoint_save_path,monitor='val_loss',verbose=1,save_best_only=True,save_weights_only=True)
history_classification = model_classification.fit(datagen_generator(images, labels, batch_size, alpha),
                                                    validation_data=train_datagen.flow(images, labels,batch_size=batch_size, subset='validation'),
                                                    steps_per_epoch=880,
                                                    epochs=200,
                                                    callbacks=[lr_reducer, checkpointer]#调整学习率和保存模型
                                                 )
# Out:
# Epoch 1/200
# 2023-10-10 03:20:56.010004: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8900
# 2023-10-10 03:20:57.820866: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-10-10 03:20:57.835000: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f66f5bdd610 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-10 03:20:57.835033: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-10-10 03:20:57.839960: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-10 03:20:58.002895: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 880/880 [==============================] - ETA: 0s - loss: 1.6507 - categorical_accuracy: 0.4980
# Epoch 1: val_loss improved from inf to 1.99833, saving model to modelsave.h5
# 880/880 [==============================] - 614s 600ms/step - loss: 1.6507 - categorical_accuracy: 0.4980 - val_loss: 1.9983 - val_categorical_accuracy: 0.3189 - lr: 0.0100
# Epoch 2/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6111 - categorical_accuracy: 0.5230
# Epoch 2: val_loss improved from 1.99833 to 1.37588, saving model to modelsave.h5
# 880/880 [==============================] - 532s 605ms/step - loss: 1.6111 - categorical_accuracy: 0.5230 - val_loss: 1.3759 - val_categorical_accuracy: 0.5664 - lr: 0.0100
# Epoch 3/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6140 - categorical_accuracy: 0.5167
# Epoch 3: val_loss did not improve from 1.37588
# 880/880 [==============================] - 495s 563ms/step - loss: 1.6140 - categorical_accuracy: 0.5167 - val_loss: 1.8123 - val_categorical_accuracy: 0.3279 - lr: 0.0100
# Epoch 4/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6197 - categorical_accuracy: 0.5197
# Epoch 4: val_loss did not improve from 1.37588
# 880/880 [==============================] - 495s 562ms/step - loss: 1.6197 - categorical_accuracy: 0.5197 - val_loss: 1.6227 - val_categorical_accuracy: 0.4260 - lr: 0.0100
# Epoch 5/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6003 - categorical_accuracy: 0.5319
# Epoch 5: val_loss did not improve from 1.37588
# 880/880 [==============================] - 495s 563ms/step - loss: 1.6003 - categorical_accuracy: 0.5319 - val_loss: 1.6202 - val_categorical_accuracy: 0.4218 - lr: 0.0100
# Epoch 6/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5944 - categorical_accuracy: 0.5386
# Epoch 6: val_loss did not improve from 1.37588
# 880/880 [==============================] - 492s 560ms/step - loss: 1.5944 - categorical_accuracy: 0.5386 - val_loss: 1.7583 - val_categorical_accuracy: 0.4364 - lr: 0.0100
# Epoch 7/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6086 - categorical_accuracy: 0.5344
# Epoch 7: val_loss did not improve from 1.37588
# 880/880 [==============================] - 492s 559ms/step - loss: 1.6086 - categorical_accuracy: 0.5344 - val_loss: 1.4448 - val_categorical_accuracy: 0.4996 - lr: 0.0100
# Epoch 8/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5907 - categorical_accuracy: 0.5427
# Epoch 8: val_loss did not improve from 1.37588
# 880/880 [==============================] - 492s 559ms/step - loss: 1.5907 - categorical_accuracy: 0.5427 - val_loss: 1.4914 - val_categorical_accuracy: 0.5207 - lr: 0.0100
# Epoch 9/200
# 880/880 [==============================] - ETA: 0s - loss: 1.6056 - categorical_accuracy: 0.5306
# Epoch 9: val_loss did not improve from 1.37588
# 880/880 [==============================] - 492s 559ms/step - loss: 1.6056 - categorical_accuracy: 0.5306 - val_loss: 1.7510 - val_categorical_accuracy: 0.3879 - lr: 0.0100
# Epoch 10/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5764 - categorical_accuracy: 0.5462
# Epoch 10: val_loss did not improve from 1.37588
# 880/880 [==============================] - 492s 559ms/step - loss: 1.5764 - categorical_accuracy: 0.5462 - val_loss: 1.5930 - val_categorical_accuracy: 0.4508 - lr: 0.0100
# Epoch 11/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5860 - categorical_accuracy: 0.5483
# Epoch 11: val_loss did not improve from 1.37588
# 880/880 [==============================] - 491s 557ms/step - loss: 1.5860 - categorical_accuracy: 0.5483 - val_loss: 1.6976 - val_categorical_accuracy: 0.3400 - lr: 0.0100
# Epoch 12/200
# 880/880 [==============================] - ETA: 0s - loss: 1.5550 - categorical_accuracy: 0.5618
# Epoch 12: val_loss did not improve from 1.37588
# 880/880 [==============================] - 492s 559ms/step - loss: 1.5550 - categorical_accuracy: 0.5618 - val_loss: 1.4423 - val_categorical_accuracy: 0.5283 - lr: 0.0100
# Epoch 13/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4492 - categorical_accuracy: 0.6158
# Epoch 13: val_loss improved from 1.37588 to 0.98027, saving model to modelsave.h5
# 880/880 [==============================] - 526s 597ms/step - loss: 1.4492 - categorical_accuracy: 0.6158 - val_loss: 0.9803 - val_categorical_accuracy: 0.6927 - lr: 0.0020
# Epoch 14/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4211 - categorical_accuracy: 0.6309
# Epoch 14: val_loss did not improve from 0.98027
# 880/880 [==============================] - 491s 558ms/step - loss: 1.4211 - categorical_accuracy: 0.6309 - val_loss: 1.0217 - val_categorical_accuracy: 0.7116 - lr: 0.0020
# Epoch 15/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4156 - categorical_accuracy: 0.6295
# Epoch 15: val_loss improved from 0.98027 to 0.94100, saving model to modelsave.h5
# 880/880 [==============================] - 520s 591ms/step - loss: 1.4156 - categorical_accuracy: 0.6295 - val_loss: 0.9410 - val_categorical_accuracy: 0.7288 - lr: 0.0020
# Epoch 16/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4152 - categorical_accuracy: 0.6312
# Epoch 16: val_loss did not improve from 0.94100
# 880/880 [==============================] - 494s 561ms/step - loss: 1.4152 - categorical_accuracy: 0.6312 - val_loss: 1.0120 - val_categorical_accuracy: 0.7107 - lr: 0.0020
# Epoch 17/200
# 880/880 [==============================] - ETA: 0s - loss: 1.4144 - categorical_accuracy: 0.6374
# Epoch 17: val_loss did not improve from 0.94100
# 880/880 [==============================] - 491s 558ms/step - loss: 1.4144 - categorical_accuracy: 0.6374 - val_loss: 1.0469 - val_categorical_accuracy: 0.7048 - lr: 0.0020
# Epoch 18/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3913 - categorical_accuracy: 0.6450
# Epoch 18: val_loss did not improve from 0.94100
# 880/880 [==============================] - 492s 559ms/step - loss: 1.3913 - categorical_accuracy: 0.6450 - val_loss: 0.9823 - val_categorical_accuracy: 0.7110 - lr: 0.0020
# Epoch 19/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3892 - categorical_accuracy: 0.6463
# Epoch 19: val_loss did not improve from 0.94100
# 880/880 [==============================] - 492s 559ms/step - loss: 1.3892 - categorical_accuracy: 0.6463 - val_loss: 0.9574 - val_categorical_accuracy: 0.7271 - lr: 0.0020
# Epoch 20/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3741 - categorical_accuracy: 0.6466
# Epoch 20: val_loss did not improve from 0.94100
# 880/880 [==============================] - 494s 562ms/step - loss: 1.3741 - categorical_accuracy: 0.6466 - val_loss: 0.9663 - val_categorical_accuracy: 0.7322 - lr: 0.0020
# Epoch 21/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3676 - categorical_accuracy: 0.6555
# Epoch 21: val_loss did not improve from 0.94100
# 880/880 [==============================] - 492s 559ms/step - loss: 1.3676 - categorical_accuracy: 0.6555 - val_loss: 1.0395 - val_categorical_accuracy: 0.6941 - lr: 0.0020
# Epoch 22/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3638 - categorical_accuracy: 0.6594
# Epoch 22: val_loss improved from 0.94100 to 0.91953, saving model to modelsave.h5
# 880/880 [==============================] - 524s 595ms/step - loss: 1.3638 - categorical_accuracy: 0.6594 - val_loss: 0.9195 - val_categorical_accuracy: 0.7291 - lr: 0.0020
# Epoch 23/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3615 - categorical_accuracy: 0.6624
# Epoch 23: val_loss did not improve from 0.91953
# 880/880 [==============================] - 496s 564ms/step - loss: 1.3615 - categorical_accuracy: 0.6624 - val_loss: 0.9378 - val_categorical_accuracy: 0.7006 - lr: 0.0020
# Epoch 24/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3524 - categorical_accuracy: 0.6623
# Epoch 24: val_loss improved from 0.91953 to 0.87643, saving model to modelsave.h5
# 880/880 [==============================] - 524s 596ms/step - loss: 1.3524 - categorical_accuracy: 0.6623 - val_loss: 0.8764 - val_categorical_accuracy: 0.7409 - lr: 0.0020
# Epoch 25/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3525 - categorical_accuracy: 0.6589
# Epoch 25: val_loss improved from 0.87643 to 0.87266, saving model to modelsave.h5
# 880/880 [==============================] - 528s 600ms/step - loss: 1.3525 - categorical_accuracy: 0.6589 - val_loss: 0.8727 - val_categorical_accuracy: 0.7370 - lr: 0.0020
# Epoch 26/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3568 - categorical_accuracy: 0.6573
# Epoch 26: val_loss did not improve from 0.87266
# 880/880 [==============================] - 496s 563ms/step - loss: 1.3568 - categorical_accuracy: 0.6573 - val_loss: 0.9293 - val_categorical_accuracy: 0.7370 - lr: 0.0020
# Epoch 27/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3493 - categorical_accuracy: 0.6586
# Epoch 27: val_loss did not improve from 0.87266
# 880/880 [==============================] - 496s 564ms/step - loss: 1.3493 - categorical_accuracy: 0.6586 - val_loss: 1.2386 - val_categorical_accuracy: 0.6011 - lr: 0.0020
# Epoch 28/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3355 - categorical_accuracy: 0.6703
# Epoch 28: val_loss did not improve from 0.87266
# 880/880 [==============================] - 496s 564ms/step - loss: 1.3355 - categorical_accuracy: 0.6703 - val_loss: 0.9233 - val_categorical_accuracy: 0.7313 - lr: 0.0020
# Epoch 29/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3105 - categorical_accuracy: 0.6832
# Epoch 29: val_loss did not improve from 0.87266
# 880/880 [==============================] - 495s 563ms/step - loss: 1.3105 - categorical_accuracy: 0.6832 - val_loss: 0.9942 - val_categorical_accuracy: 0.6919 - lr: 0.0020
# Epoch 30/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3338 - categorical_accuracy: 0.6683
# Epoch 30: val_loss improved from 0.87266 to 0.84690, saving model to modelsave.h5
# 880/880 [==============================] - 524s 595ms/step - loss: 1.3338 - categorical_accuracy: 0.6683 - val_loss: 0.8469 - val_categorical_accuracy: 0.7474 - lr: 0.0020
# Epoch 31/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3259 - categorical_accuracy: 0.6668
# Epoch 31: val_loss did not improve from 0.84690
# 880/880 [==============================] - 496s 564ms/step - loss: 1.3259 - categorical_accuracy: 0.6668 - val_loss: 0.9411 - val_categorical_accuracy: 0.7102 - lr: 0.0020
# Epoch 32/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3173 - categorical_accuracy: 0.6718
# Epoch 32: val_loss did not improve from 0.84690
# 880/880 [==============================] - 496s 563ms/step - loss: 1.3173 - categorical_accuracy: 0.6718 - val_loss: 0.8572 - val_categorical_accuracy: 0.7584 - lr: 0.0020
# Epoch 33/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3099 - categorical_accuracy: 0.6788
# Epoch 33: val_loss did not improve from 0.84690
# 880/880 [==============================] - 496s 563ms/step - loss: 1.3099 - categorical_accuracy: 0.6788 - val_loss: 1.0335 - val_categorical_accuracy: 0.6563 - lr: 0.0020
# Epoch 34/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3106 - categorical_accuracy: 0.6764
# Epoch 34: val_loss did not improve from 0.84690
# 880/880 [==============================] - 497s 565ms/step - loss: 1.3106 - categorical_accuracy: 0.6764 - val_loss: 0.8499 - val_categorical_accuracy: 0.7632 - lr: 0.0020
# Epoch 35/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3035 - categorical_accuracy: 0.6839
# Epoch 35: val_loss improved from 0.84690 to 0.78425, saving model to modelsave.h5
# 880/880 [==============================] - 522s 593ms/step - loss: 1.3035 - categorical_accuracy: 0.6839 - val_loss: 0.7843 - val_categorical_accuracy: 0.7725 - lr: 0.0020
# Epoch 36/200
# 880/880 [==============================] - ETA: 0s - loss: 1.3108 - categorical_accuracy: 0.6809
# Epoch 36: val_loss did not improve from 0.78425
# 880/880 [==============================] - 496s 564ms/step - loss: 1.3108 - categorical_accuracy: 0.6809 - val_loss: 0.9150 - val_categorical_accuracy: 0.7186 - lr: 0.0020
# Epoch 37/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2940 - categorical_accuracy: 0.6801
# Epoch 37: val_loss did not improve from 0.78425
# 880/880 [==============================] - 497s 565ms/step - loss: 1.2940 - categorical_accuracy: 0.6801 - val_loss: 0.8346 - val_categorical_accuracy: 0.7505 - lr: 0.0020
# Epoch 38/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2961 - categorical_accuracy: 0.6853
# Epoch 38: val_loss did not improve from 0.78425
# 880/880 [==============================] - 496s 563ms/step - loss: 1.2961 - categorical_accuracy: 0.6853 - val_loss: 0.9383 - val_categorical_accuracy: 0.7110 - lr: 0.0020
# Epoch 39/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2879 - categorical_accuracy: 0.6872
# Epoch 39: val_loss improved from 0.78425 to 0.77746, saving model to modelsave.h5
# 880/880 [==============================] - 524s 595ms/step - loss: 1.2879 - categorical_accuracy: 0.6872 - val_loss: 0.7775 - val_categorical_accuracy: 0.7773 - lr: 0.0020
# Epoch 40/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2743 - categorical_accuracy: 0.6890
# Epoch 40: val_loss did not improve from 0.77746
# 880/880 [==============================] - 495s 563ms/step - loss: 1.2743 - categorical_accuracy: 0.6890 - val_loss: 0.9257 - val_categorical_accuracy: 0.7088 - lr: 0.0020
# Epoch 41/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2787 - categorical_accuracy: 0.6839
# Epoch 41: val_loss did not improve from 0.77746
# 880/880 [==============================] - 496s 564ms/step - loss: 1.2787 - categorical_accuracy: 0.6839 - val_loss: 0.8574 - val_categorical_accuracy: 0.7454 - lr: 0.0020
# Epoch 42/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2775 - categorical_accuracy: 0.6871
# Epoch 42: val_loss did not improve from 0.77746
# 880/880 [==============================] - 496s 564ms/step - loss: 1.2775 - categorical_accuracy: 0.6871 - val_loss: 0.8324 - val_categorical_accuracy: 0.7666 - lr: 0.0020
# Epoch 43/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2749 - categorical_accuracy: 0.6894
# Epoch 43: val_loss did not improve from 0.77746
# 880/880 [==============================] - 496s 564ms/step - loss: 1.2749 - categorical_accuracy: 0.6894 - val_loss: 0.9291 - val_categorical_accuracy: 0.7344 - lr: 0.0020
# Epoch 44/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2633 - categorical_accuracy: 0.6928
# Epoch 44: val_loss did not improve from 0.77746
# 880/880 [==============================] - 497s 565ms/step - loss: 1.2633 - categorical_accuracy: 0.6928 - val_loss: 0.8364 - val_categorical_accuracy: 0.7635 - lr: 0.0020
# Epoch 45/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2649 - categorical_accuracy: 0.6985
# Epoch 45: val_loss did not improve from 0.77746
# 880/880 [==============================] - 492s 559ms/step - loss: 1.2649 - categorical_accuracy: 0.6985 - val_loss: 0.8501 - val_categorical_accuracy: 0.7333 - lr: 0.0020
# Epoch 46/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2551 - categorical_accuracy: 0.6936
# Epoch 46: val_loss improved from 0.77746 to 0.75979, saving model to modelsave.h5
# 880/880 [==============================] - 524s 595ms/step - loss: 1.2551 - categorical_accuracy: 0.6936 - val_loss: 0.7598 - val_categorical_accuracy: 0.7821 - lr: 0.0020
# Epoch 47/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2484 - categorical_accuracy: 0.6945
# Epoch 47: val_loss did not improve from 0.75979
# 880/880 [==============================] - 494s 562ms/step - loss: 1.2484 - categorical_accuracy: 0.6945 - val_loss: 0.8554 - val_categorical_accuracy: 0.7635 - lr: 0.0020
# Epoch 48/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2638 - categorical_accuracy: 0.6945
# Epoch 48: val_loss did not improve from 0.75979
# 880/880 [==============================] - 496s 564ms/step - loss: 1.2638 - categorical_accuracy: 0.6945 - val_loss: 0.8319 - val_categorical_accuracy: 0.7722 - lr: 0.0020
# Epoch 49/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2507 - categorical_accuracy: 0.6916
# Epoch 49: val_loss did not improve from 0.75979
# 880/880 [==============================] - 496s 564ms/step - loss: 1.2507 - categorical_accuracy: 0.6916 - val_loss: 0.8044 - val_categorical_accuracy: 0.7516 - lr: 0.0020
# Epoch 50/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2433 - categorical_accuracy: 0.6972
# Epoch 50: val_loss did not improve from 0.75979
# 880/880 [==============================] - 497s 564ms/step - loss: 1.2433 - categorical_accuracy: 0.6972 - val_loss: 0.9868 - val_categorical_accuracy: 0.7229 - lr: 0.0020
# Epoch 51/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2467 - categorical_accuracy: 0.7016
# Epoch 51: val_loss did not improve from 0.75979
# 880/880 [==============================] - 496s 564ms/step - loss: 1.2467 - categorical_accuracy: 0.7016 - val_loss: 0.8080 - val_categorical_accuracy: 0.7626 - lr: 0.0020
# Epoch 52/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2331 - categorical_accuracy: 0.7051
# Epoch 52: val_loss did not improve from 0.75979
# 880/880 [==============================] - 496s 564ms/step - loss: 1.2331 - categorical_accuracy: 0.7051 - val_loss: 0.7652 - val_categorical_accuracy: 0.7750 - lr: 0.0020
# Epoch 53/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2341 - categorical_accuracy: 0.7027
# Epoch 53: val_loss did not improve from 0.75979
# 880/880 [==============================] - 496s 564ms/step - loss: 1.2341 - categorical_accuracy: 0.7027 - val_loss: 0.9515 - val_categorical_accuracy: 0.7262 - lr: 0.0020
# Epoch 54/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2184 - categorical_accuracy: 0.7078
# Epoch 54: val_loss did not improve from 0.75979
# 880/880 [==============================] - 495s 563ms/step - loss: 1.2184 - categorical_accuracy: 0.7078 - val_loss: 0.8053 - val_categorical_accuracy: 0.7491 - lr: 0.0020
# Epoch 55/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2198 - categorical_accuracy: 0.7063
# Epoch 55: val_loss did not improve from 0.75979
# 880/880 [==============================] - 496s 564ms/step - loss: 1.2198 - categorical_accuracy: 0.7063 - val_loss: 0.7731 - val_categorical_accuracy: 0.7728 - lr: 0.0020
# Epoch 56/200
# 880/880 [==============================] - ETA: 0s - loss: 1.2121 - categorical_accuracy: 0.7163
# Epoch 56: val_loss did not improve from 0.75979
# 880/880 [==============================] - 495s 563ms/step - loss: 1.2121 - categorical_accuracy: 0.7163 - val_loss: 0.9067 - val_categorical_accuracy: 0.7265 - lr: 0.0020
# Epoch 57/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1926 - categorical_accuracy: 0.7154
# Epoch 57: val_loss improved from 0.75979 to 0.65974, saving model to modelsave.h5
# 880/880 [==============================] - 525s 597ms/step - loss: 1.1926 - categorical_accuracy: 0.7154 - val_loss: 0.6597 - val_categorical_accuracy: 0.8012 - lr: 4.0000e-04
# Epoch 58/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1754 - categorical_accuracy: 0.7279
# Epoch 58: val_loss did not improve from 0.65974
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1754 - categorical_accuracy: 0.7279 - val_loss: 0.6619 - val_categorical_accuracy: 0.8089 - lr: 4.0000e-04
# Epoch 59/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1697 - categorical_accuracy: 0.7251
# Epoch 59: val_loss improved from 0.65974 to 0.63135, saving model to modelsave.h5
# 880/880 [==============================] - 522s 593ms/step - loss: 1.1697 - categorical_accuracy: 0.7251 - val_loss: 0.6313 - val_categorical_accuracy: 0.8125 - lr: 4.0000e-04
# Epoch 60/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1634 - categorical_accuracy: 0.7278
# Epoch 60: val_loss did not improve from 0.63135
# 880/880 [==============================] - 495s 562ms/step - loss: 1.1634 - categorical_accuracy: 0.7278 - val_loss: 0.6479 - val_categorical_accuracy: 0.8117 - lr: 4.0000e-04
# Epoch 61/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1623 - categorical_accuracy: 0.7286
# Epoch 61: val_loss improved from 0.63135 to 0.62855, saving model to modelsave.h5
# 880/880 [==============================] - 522s 593ms/step - loss: 1.1623 - categorical_accuracy: 0.7286 - val_loss: 0.6285 - val_categorical_accuracy: 0.8083 - lr: 4.0000e-04
# Epoch 62/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1615 - categorical_accuracy: 0.7338
# Epoch 62: val_loss did not improve from 0.62855
# 880/880 [==============================] - 496s 563ms/step - loss: 1.1615 - categorical_accuracy: 0.7338 - val_loss: 0.6475 - val_categorical_accuracy: 0.8091 - lr: 4.0000e-04
# Epoch 63/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1539 - categorical_accuracy: 0.7343
# Epoch 63: val_loss did not improve from 0.62855
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1539 - categorical_accuracy: 0.7343 - val_loss: 0.6378 - val_categorical_accuracy: 0.8151 - lr: 4.0000e-04
# Epoch 64/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1484 - categorical_accuracy: 0.7333
# Epoch 64: val_loss did not improve from 0.62855
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1484 - categorical_accuracy: 0.7333 - val_loss: 0.6344 - val_categorical_accuracy: 0.8117 - lr: 4.0000e-04
# Epoch 65/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1649 - categorical_accuracy: 0.7241
# Epoch 65: val_loss did not improve from 0.62855
# 880/880 [==============================] - 496s 563ms/step - loss: 1.1649 - categorical_accuracy: 0.7241 - val_loss: 0.6426 - val_categorical_accuracy: 0.8114 - lr: 4.0000e-04
# Epoch 66/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1538 - categorical_accuracy: 0.7315
# Epoch 66: val_loss did not improve from 0.62855
# 880/880 [==============================] - 496s 563ms/step - loss: 1.1538 - categorical_accuracy: 0.7315 - val_loss: 0.6455 - val_categorical_accuracy: 0.8066 - lr: 4.0000e-04
# Epoch 67/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1458 - categorical_accuracy: 0.7325
# Epoch 67: val_loss improved from 0.62855 to 0.62755, saving model to modelsave.h5
# 880/880 [==============================] - 523s 595ms/step - loss: 1.1458 - categorical_accuracy: 0.7325 - val_loss: 0.6275 - val_categorical_accuracy: 0.8086 - lr: 4.0000e-04
# Epoch 68/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1502 - categorical_accuracy: 0.7304
# Epoch 68: val_loss improved from 0.62755 to 0.62061, saving model to modelsave.h5
# 880/880 [==============================] - 524s 596ms/step - loss: 1.1502 - categorical_accuracy: 0.7304 - val_loss: 0.6206 - val_categorical_accuracy: 0.8159 - lr: 4.0000e-04
# Epoch 69/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1449 - categorical_accuracy: 0.7330
# Epoch 69: val_loss improved from 0.62061 to 0.61478, saving model to modelsave.h5
# 880/880 [==============================] - 523s 594ms/step - loss: 1.1449 - categorical_accuracy: 0.7330 - val_loss: 0.6148 - val_categorical_accuracy: 0.8125 - lr: 4.0000e-04
# Epoch 70/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1500 - categorical_accuracy: 0.7278
# Epoch 70: val_loss did not improve from 0.61478
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1500 - categorical_accuracy: 0.7278 - val_loss: 0.6350 - val_categorical_accuracy: 0.8179 - lr: 4.0000e-04
# Epoch 71/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1475 - categorical_accuracy: 0.7306
# Epoch 71: val_loss did not improve from 0.61478
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1475 - categorical_accuracy: 0.7306 - val_loss: 0.6171 - val_categorical_accuracy: 0.8196 - lr: 4.0000e-04
# Epoch 72/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1414 - categorical_accuracy: 0.7420
# Epoch 72: val_loss improved from 0.61478 to 0.60508, saving model to modelsave.h5
# 880/880 [==============================] - 526s 598ms/step - loss: 1.1414 - categorical_accuracy: 0.7420 - val_loss: 0.6051 - val_categorical_accuracy: 0.8190 - lr: 4.0000e-04
# Epoch 73/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1452 - categorical_accuracy: 0.7318
# Epoch 73: val_loss did not improve from 0.60508
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1452 - categorical_accuracy: 0.7318 - val_loss: 0.6064 - val_categorical_accuracy: 0.8122 - lr: 4.0000e-04
# Epoch 74/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1478 - categorical_accuracy: 0.7303
# Epoch 74: val_loss did not improve from 0.60508
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1478 - categorical_accuracy: 0.7303 - val_loss: 0.6167 - val_categorical_accuracy: 0.8156 - lr: 4.0000e-04
# Epoch 75/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1426 - categorical_accuracy: 0.7420
# Epoch 75: val_loss did not improve from 0.60508
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1426 - categorical_accuracy: 0.7420 - val_loss: 0.6169 - val_categorical_accuracy: 0.8170 - lr: 4.0000e-04
# Epoch 76/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1491 - categorical_accuracy: 0.7293
# Epoch 76: val_loss did not improve from 0.60508
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1491 - categorical_accuracy: 0.7293 - val_loss: 0.6244 - val_categorical_accuracy: 0.8148 - lr: 4.0000e-04
# Epoch 77/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1250 - categorical_accuracy: 0.7360
# Epoch 77: val_loss did not improve from 0.60508
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1250 - categorical_accuracy: 0.7360 - val_loss: 0.6114 - val_categorical_accuracy: 0.8198 - lr: 4.0000e-04
# Epoch 78/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1329 - categorical_accuracy: 0.7326
# Epoch 78: val_loss did not improve from 0.60508
# 880/880 [==============================] - 494s 562ms/step - loss: 1.1329 - categorical_accuracy: 0.7326 - val_loss: 0.6321 - val_categorical_accuracy: 0.8060 - lr: 4.0000e-04
# Epoch 79/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1315 - categorical_accuracy: 0.7394
# Epoch 79: val_loss did not improve from 0.60508
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1315 - categorical_accuracy: 0.7394 - val_loss: 0.6109 - val_categorical_accuracy: 0.8136 - lr: 4.0000e-04
# Epoch 80/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1466 - categorical_accuracy: 0.7285
# Epoch 80: val_loss did not improve from 0.60508
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1466 - categorical_accuracy: 0.7285 - val_loss: 0.6068 - val_categorical_accuracy: 0.8145 - lr: 4.0000e-04
# Epoch 81/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1162 - categorical_accuracy: 0.7466
# Epoch 81: val_loss did not improve from 0.60508
# 880/880 [==============================] - 495s 562ms/step - loss: 1.1162 - categorical_accuracy: 0.7466 - val_loss: 0.6141 - val_categorical_accuracy: 0.8114 - lr: 4.0000e-04
# Epoch 82/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1380 - categorical_accuracy: 0.7382
# Epoch 82: val_loss did not improve from 0.60508
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1380 - categorical_accuracy: 0.7382 - val_loss: 0.6582 - val_categorical_accuracy: 0.8043 - lr: 4.0000e-04
# Epoch 83/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1325 - categorical_accuracy: 0.7378
# Epoch 83: val_loss improved from 0.60508 to 0.59168, saving model to modelsave.h5
# 880/880 [==============================] - 524s 596ms/step - loss: 1.1325 - categorical_accuracy: 0.7378 - val_loss: 0.5917 - val_categorical_accuracy: 0.8173 - lr: 8.0000e-05
# Epoch 84/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1166 - categorical_accuracy: 0.7485
# Epoch 84: val_loss improved from 0.59168 to 0.58895, saving model to modelsave.h5
# 880/880 [==============================] - 524s 595ms/step - loss: 1.1166 - categorical_accuracy: 0.7485 - val_loss: 0.5889 - val_categorical_accuracy: 0.8244 - lr: 8.0000e-05
# Epoch 85/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1193 - categorical_accuracy: 0.7366
# Epoch 85: val_loss improved from 0.58895 to 0.58081, saving model to modelsave.h5
# 880/880 [==============================] - 523s 594ms/step - loss: 1.1193 - categorical_accuracy: 0.7366 - val_loss: 0.5808 - val_categorical_accuracy: 0.8227 - lr: 8.0000e-05
# Epoch 86/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1217 - categorical_accuracy: 0.7445
# Epoch 86: val_loss did not improve from 0.58081
# 880/880 [==============================] - 495s 562ms/step - loss: 1.1217 - categorical_accuracy: 0.7445 - val_loss: 0.5851 - val_categorical_accuracy: 0.8241 - lr: 8.0000e-05
# Epoch 87/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1235 - categorical_accuracy: 0.7383
# Epoch 87: val_loss did not improve from 0.58081
# 880/880 [==============================] - 496s 563ms/step - loss: 1.1235 - categorical_accuracy: 0.7383 - val_loss: 0.5821 - val_categorical_accuracy: 0.8229 - lr: 8.0000e-05
# Epoch 88/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1067 - categorical_accuracy: 0.7461
# Epoch 88: val_loss improved from 0.58081 to 0.58055, saving model to modelsave.h5
# 880/880 [==============================] - 525s 597ms/step - loss: 1.1067 - categorical_accuracy: 0.7461 - val_loss: 0.5805 - val_categorical_accuracy: 0.8215 - lr: 8.0000e-05
# Epoch 89/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1147 - categorical_accuracy: 0.7382
# Epoch 89: val_loss did not improve from 0.58055
# 880/880 [==============================] - 495s 562ms/step - loss: 1.1147 - categorical_accuracy: 0.7382 - val_loss: 0.5823 - val_categorical_accuracy: 0.8258 - lr: 8.0000e-05
# Epoch 90/200
# 880/880 [==============================] - ETA: 0s - loss: 1.1152 - categorical_accuracy: 0.7411
# Epoch 90: val_loss did not improve from 0.58055
# 880/880 [==============================] - 495s 563ms/step - loss: 1.1152 - categorical_accuracy: 0.7411 - val_loss: 0.5809 - val_categorical_accuracy: 0.8227 - lr: 8.0000e-05
# Epoch 91/200
# 112/880 [==>...........................] - ETA: 6:35 - loss: 1.0868 - categorical_accuracy: 0.7628

# %%
print(history_classification.history)

# %%
fig1 = plt.figure(num="model regularize", figsize=(8, 6))
ax1 = fig1.add_subplot(111)
ax1.plot(history_classification.history['categorical_accuracy'], label='train accuracy', color='b')
ax1.plot(history_classification.history['val_categorical_accuracy'], label='val accuracy', color='g')
ax1.legend(loc = 'upper center')
ax1.set_xlabel('epoch')
ax1.set_ylabel('accuracy');
ax2 = ax1.twinx()
ax2.plot(history_classification.history['loss'], label="train loss", color='r')
ax2.plot(history_classification.history['val_loss'], label="val loss", color='y')
ax2.legend(loc=2)
ax2.set_ylabel('loss');
ax2.legend(loc = 'lower center')
plt.show()
